# %%
# !pip install --upgrade boto3
# !pip install --upgrade sagemaker
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Requirement already satisfied: boto3 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (1.26.139)
# Collecting boto3
#   Downloading boto3-1.26.143-py3-none-any.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.6/135.6 kB 23.0 MB/s eta 0:00:00
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from boto3) (0.6.0)
# Collecting botocore<1.30.0,>=1.29.143
#   Downloading botocore-1.29.143-py3-none-any.whl (10.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 118.8 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from boto3) (1.0.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from botocore<1.30.0,>=1.29.143->boto3) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from botocore<1.30.0,>=1.29.143->boto3) (1.26.8)
# Requirement already satisfied: six>=1.5 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.30.0,>=1.29.143->boto3) (1.16.0)
# Installing collected packages: botocore, boto3
#   Attempting uninstall: botocore
#     Found existing installation: botocore 1.29.139
#     Uninstalling botocore-1.29.139:
#       Successfully uninstalled botocore-1.29.139
#   Attempting uninstall: boto3
#     Found existing installation: boto3 1.26.139
#     Uninstalling boto3-1.26.139:
#       Successfully uninstalled boto3-1.26.139
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# awscli 1.27.125 requires botocore==1.29.125, but you have botocore 1.29.143 which is incompatible.
# awscli 1.27.125 requires PyYAML<5.5,>=3.10, but you have pyyaml 6.0 which is incompatible.
# Successfully installed boto3-1.26.143 botocore-1.29.143
#
# Usage:
#   pip install [options] <requirement specifier> [package-index-options] ...
#   pip install [options] -r <requirements file> [package-index-options] ...
#   pip install [options] [-e] <vcs project url> ...
#   pip install [options] [-e] <local project path> ...
#   pip install [options] <archive url/path> ...
#
# no such option: --upgradesagemaker

# %%
# For notebook instances (Amazon Linux)
# !sudo yum update -y
# !sudo yum install amazon-linux-extras
# !sudo amazon-linux-extras install epel -y
# !sudo yum update -y
# !sudo yum install git-lfs git -y
# Out:
# Loaded plugins: dkms-build-requires, extras_suggestions, langpacks, priorities,
#               : update-motd, versionlock
# amzn2-core                                               | 3.7 kB     00:00
# amzn2extra-docker                                        | 3.0 kB     00:00
# amzn2extra-kernel-5.10                                   | 3.0 kB     00:00
# amzn2extra-python3.8                                     | 3.0 kB     00:00
# centos-extras                                            | 2.9 kB     00:00
# copr:copr.fedorainfracloud.org:vbatts:shadow-utils-newxi | 3.3 kB     00:00
# https://download.docker.com/linux/centos/2/x86_64/stable/repodata/repomd.xml: [Errno 14] HTTPS Error 404 - Not Found
# Trying other mirror.
# libnvidia-container/x86_64/signature                     |  833 B     00:00
# libnvidia-container/x86_64/signature                     | 2.1 kB     00:00 !!!
# neuron                                                   | 2.9 kB     00:00
# (1/2): libnvidia-container/x86_64/primary                  |  32 kB   00:00
# (2/2): neuron/primary_db                                   | 143 kB   00:00
# libnvidia-container                                                     211/211
# 61 packages excluded due to repository priority protections
# Resolving Dependencies
# --> Running transaction check
# ---> Package amazon-cloudwatch-agent.x86_64 0:1.247359.1b252618-1 will be updated
# ---> Package amazon-cloudwatch-agent.x86_64 0:1.300026.2-1.amzn2 will be an update
# ---> Package avahi-glib.x86_64 0:0.6.31-20.amzn2 will be updated
# ---> Package avahi-glib.x86_64 0:0.6.31-20.amzn2.0.2 will be an update
# ---> Package avahi-libs.x86_64 0:0.6.31-20.amzn2 will be updated
# ---> Package avahi-libs.x86_64 0:0.6.31-20.amzn2.0.2 will be an update
# ---> Package bind-export-libs.x86_64 32:9.11.4-26.P2.amzn2.13 will be updated
# ---> Package bind-export-libs.x86_64 32:9.11.4-26.P2.amzn2.13.1 will be an update
# ---> Package bind-libs.x86_64 32:9.11.4-26.P2.amzn2.13 will be updated
# ---> Package bind-libs.x86_64 32:9.11.4-26.P2.amzn2.13.1 will be an update
# ---> Package bind-libs-lite.x86_64 32:9.11.4-26.P2.amzn2.13 will be updated
# ---> Package bind-libs-lite.x86_64 32:9.11.4-26.P2.amzn2.13.1 will be an update
# ---> Package bind-license.noarch 32:9.11.4-26.P2.amzn2.13 will be updated
# ---> Package bind-license.noarch 32:9.11.4-26.P2.amzn2.13.1 will be an update
# ---> Package bind-utils.x86_64 32:9.11.4-26.P2.amzn2.13 will be updated
# ---> Package bind-utils.x86_64 32:9.11.4-26.P2.amzn2.13.1 will be an update
# ---> Package cloud-init.noarch 0:19.3-46.amzn2 will be updated
# ---> Package cloud-init.noarch 0:19.3-46.amzn2.0.1 will be an update
# ---> Package containerd.x86_64 0:1.6.19-1.amzn2.0.1 will be updated
# ---> Package containerd.x86_64 0:1.6.19-1.amzn2.0.3 will be an update
# ---> Package cups-libs.x86_64 1:1.6.3-51.amzn2 will be updated
# ---> Package cups-libs.x86_64 1:1.6.3-51.amzn2.0.2 will be an update
# ---> Package elfutils.x86_64 0:0.176-2.amzn2 will be updated
# ---> Package elfutils.x86_64 0:0.176-2.amzn2.0.1 will be an update
# ---> Package elfutils-default-yama-scope.noarch 0:0.176-2.amzn2 will be updated
# ---> Package elfutils-default-yama-scope.noarch 0:0.176-2.amzn2.0.1 will be an update
# ---> Package elfutils-libelf.x86_64 0:0.176-2.amzn2 will be updated
# ---> Package elfutils-libelf.x86_64 0:0.176-2.amzn2.0.1 will be an update
# ---> Package elfutils-libelf-devel.x86_64 0:0.176-2.amzn2 will be updated
# ---> Package elfutils-libelf-devel.x86_64 0:0.176-2.amzn2.0.1 will be an update
# ---> Package elfutils-libs.x86_64 0:0.176-2.amzn2 will be updated
# ---> Package elfutils-libs.x86_64 0:0.176-2.amzn2.0.1 will be an update
# ---> Package flac-libs.x86_64 0:1.3.0-5.amzn2.0.2 will be updated
# ---> Package flac-libs.x86_64 0:1.3.0-5.amzn2.0.4 will be an update
# ---> Package fribidi.x86_64 0:1.0.2-1.amzn2.1.1 will be updated
# ---> Package fribidi.x86_64 0:1.0.2-1.amzn2.1.2 will be an update
# ---> Package fuse-overlayfs.x86_64 0:0.7.2-6.amzn2int will be updated
# ---> Package fuse-overlayfs.x86_64 0:0.7.2-6.el7_8 will be an update
# ---> Package glib2.x86_64 0:2.56.1-9.amzn2.0.5 will be updated
# ---> Package glib2.x86_64 0:2.56.1-9.amzn2.0.6 will be an update
# ---> Package grub2.x86_64 1:2.06-9.amzn2.0.1 will be obsoleted
# ---> Package grub2.x86_64 1:2.06-14.amzn2.0.1 will be obsoleting
# ---> Package grub2-common.noarch 1:2.06-9.amzn2.0.1 will be updated
# ---> Package grub2-common.noarch 1:2.06-14.amzn2.0.1 will be an update
# ---> Package grub2-efi-x64-ec2.x86_64 1:2.06-9.amzn2.0.1 will be updated
# ---> Package grub2-efi-x64-ec2.x86_64 1:2.06-14.amzn2.0.1 will be an update
# ---> Package grub2-pc.x86_64 1:2.06-9.amzn2.0.1 will be updated
# ---> Package grub2-pc.x86_64 1:2.06-14.amzn2.0.1 will be obsoleting
# ---> Package grub2-pc-modules.noarch 1:2.06-9.amzn2.0.1 will be updated
# ---> Package grub2-pc-modules.noarch 1:2.06-14.amzn2.0.1 will be an update
# ---> Package grub2-tools.x86_64 1:2.06-9.amzn2.0.1 will be obsoleted
# ---> Package grub2-tools.x86_64 1:2.06-14.amzn2.0.1 will be obsoleting
# ---> Package grub2-tools-efi.x86_64 1:2.06-14.amzn2.0.1 will be obsoleting
# ---> Package grub2-tools-extra.x86_64 1:2.06-14.amzn2.0.1 will be obsoleting
# ---> Package grub2-tools-minimal.x86_64 1:2.06-9.amzn2.0.1 will be updated
# ---> Package grub2-tools-minimal.x86_64 1:2.06-14.amzn2.0.1 will be obsoleting
# ---> Package gstreamer1.x86_64 0:1.10.4-2.amzn2.0.2 will be updated
# ---> Package gstreamer1.x86_64 0:1.18.4-4.amzn2.0.1 will be an update
# ---> Package gstreamer1-plugins-bad-free.x86_64 0:1.10.4-3.amzn2 will be updated
# ---> Package gstreamer1-plugins-bad-free.x86_64 0:1.18.4-5.amzn2.0.1 will be an update
# --> Processing Dependency: libwebrtc_audio_processing.so.1()(64bit) for package: gstreamer1-plugins-bad-free-1.18.4-5.amzn2.0.1.x86_64
# --> Processing Dependency: libgudev-1.0.so.0()(64bit) for package: gstreamer1-plugins-bad-free-1.18.4-5.amzn2.0.1.x86_64
# ---> Package gstreamer1-plugins-base.x86_64 0:1.10.4-2.amzn2.0.3 will be updated
# ---> Package gstreamer1-plugins-base.x86_64 0:1.18.4-5.amzn2.0.3 will be an update
# --> Processing Dependency: libgraphene-1.0.so.0()(64bit) for package: gstreamer1-plugins-base-1.18.4-5.amzn2.0.3.x86_64
# ---> Package hibagent.noarch 0:1.1.0-5.amzn2 will be updated
# ---> Package hibagent.noarch 0:1.1.0-6.amzn2 will be an update
# ---> Package ibacm.x86_64 0:41.0-2.amzn2.0.2 will be updated
# ---> Package ibacm.x86_64 0:43.0-1.amzn2.0.2 will be an update
# ---> Package infiniband-diags.x86_64 0:41.0-2.amzn2.0.2 will be updated
# ---> Package infiniband-diags.x86_64 0:43.0-1.amzn2.0.2 will be an update
# ---> Package iputils.x86_64 0:20160308-10.amzn2.0.2 will be updated
# ---> Package iputils.x86_64 0:20180629-11.amzn2.1.20160308 will be an update
# ---> Package iso-codes.noarch 0:3.46-2.amzn2 will be updated
# ---> Package iso-codes.noarch 0:4.6.0-3.amzn2 will be an update
# ---> Package java-11-amazon-corretto-headless.x86_64 1:11.0.19+7-1.amzn2 will be updated
# ---> Package java-11-amazon-corretto-headless.x86_64 1:11.0.20+8-1.amzn2 will be an update
# ---> Package kernel-devel.x86_64 0:5.10.186-179.751.amzn2 will be installed
# ---> Package kernel-headers.x86_64 0:5.10.179-171.711.amzn2 will be updated
# ---> Package kernel-headers.x86_64 0:5.10.186-179.751.amzn2 will be an update
# ---> Package kpatch-runtime.noarch 0:0.9.4-7.amzn2 will be updated
# ---> Package kpatch-runtime.noarch 0:0.9.4-8.amzn2 will be an update
# ---> Package libX11.x86_64 0:1.6.7-3.amzn2.0.2 will be updated
# ---> Package libX11.x86_64 0:1.6.7-3.amzn2.0.3 will be an update
# ---> Package libX11-common.noarch 0:1.6.7-3.amzn2.0.2 will be updated
# ---> Package libX11-common.noarch 0:1.6.7-3.amzn2.0.3 will be an update
# ---> Package libcap.x86_64 0:2.54-1.amzn2.0.1 will be updated
# ---> Package libcap.x86_64 0:2.54-1.amzn2.0.2 will be an update
# ---> Package libgs.x86_64 0:9.25-5.amzn2.0.3 will be updated
# ---> Package libgs.x86_64 0:9.25-5.amzn2.0.4 will be an update
# ---> Package libibumad.x86_64 0:41.0-2.amzn2.0.2 will be updated
# ---> Package libibumad.x86_64 0:43.0-1.amzn2.0.2 will be an update
# ---> Package libibverbs.x86_64 0:41.0-2.amzn2.0.2 will be updated
# ---> Package libibverbs.x86_64 0:43.0-1.amzn2.0.2 will be an update
# ---> Package libibverbs-core.x86_64 0:41.0-2.amzn2.0.2 will be updated
# ---> Package libibverbs-core.x86_64 0:43.0-1.amzn2.0.2 will be an update
# ---> Package libibverbs-utils.x86_64 0:41.0-2.amzn2.0.2 will be updated
# ---> Package libibverbs-utils.x86_64 0:43.0-1.amzn2.0.2 will be an update
# ---> Package libicu.x86_64 0:50.2-4.amzn2 will be updated
# ---> Package libicu.x86_64 0:50.2-4.amzn2.0.1 will be an update
# ---> Package libjpeg-turbo.x86_64 0:2.0.90-2.amzn2.0.1 will be updated
# ---> Package libjpeg-turbo.x86_64 0:2.0.90-2.amzn2.0.2 will be an update
# ---> Package libjpeg-turbo-devel.x86_64 0:2.0.90-2.amzn2.0.1 will be updated
# ---> Package libjpeg-turbo-devel.x86_64 0:2.0.90-2.amzn2.0.2 will be an update
# ---> Package libnghttp2.x86_64 0:1.41.0-1.amzn2 will be updated
# ---> Package libnghttp2.x86_64 0:1.41.0-1.amzn2.0.1 will be an update
# ---> Package libnvidia-container-tools.x86_64 0:1.13.1-1 will be updated
# ---> Package libnvidia-container-tools.x86_64 0:1.13.5-1 will be an update
# ---> Package libnvidia-container1.x86_64 0:1.13.1-1 will be updated
# ---> Package libnvidia-container1.x86_64 0:1.13.5-1 will be an update
# ---> Package librdmacm.x86_64 0:41.0-2.amzn2.0.2 will be updated
# ---> Package librdmacm.x86_64 0:43.0-1.amzn2.0.2 will be an update
# ---> Package librdmacm-utils.x86_64 0:41.0-2.amzn2.0.2 will be updated
# ---> Package librdmacm-utils.x86_64 0:43.0-1.amzn2.0.2 will be an update
# ---> Package libtiff.x86_64 0:4.0.3-35.amzn2.0.6 will be updated
# ---> Package libtiff.x86_64 0:4.0.3-35.amzn2.0.9 will be an update
# ---> Package libwayland-client.x86_64 0:1.17.0-1.amzn2 will be updated
# ---> Package libwayland-client.x86_64 0:1.17.0-1.amzn2.0.1 will be an update
# ---> Package libwayland-cursor.x86_64 0:1.17.0-1.amzn2 will be updated
# ---> Package libwayland-cursor.x86_64 0:1.17.0-1.amzn2.0.1 will be an update
# ---> Package libwayland-egl.x86_64 0:1.17.0-1.amzn2 will be updated
# ---> Package libwayland-egl.x86_64 0:1.17.0-1.amzn2.0.1 will be an update
# ---> Package libwayland-server.x86_64 0:1.17.0-1.amzn2 will be updated
# ---> Package libwayland-server.x86_64 0:1.17.0-1.amzn2.0.1 will be an update
# ---> Package libzstd.x86_64 0:1.5.2-1.amzn2 will be updated
# ---> Package libzstd.x86_64 0:1.5.2-1.amzn2.0.1 will be an update
# ---> Package microcode_ctl.x86_64 2:2.1-47.amzn2.0.15 will be updated
# ---> Package microcode_ctl.x86_64 2:2.1-47.amzn2.1.15 will be an update
# ---> Package ncurses.x86_64 0:6.0-8.20170212.amzn2.1.4 will be updated
# ---> Package ncurses.x86_64 0:6.0-8.20170212.amzn2.1.5 will be an update
# ---> Package ncurses-base.noarch 0:6.0-8.20170212.amzn2.1.4 will be updated
# ---> Package ncurses-base.noarch 0:6.0-8.20170212.amzn2.1.5 will be an update
# ---> Package ncurses-libs.x86_64 0:6.0-8.20170212.amzn2.1.4 will be updated
# ---> Package ncurses-libs.x86_64 0:6.0-8.20170212.amzn2.1.5 will be an update
# ---> Package nvidia-container-toolkit.x86_64 0:1.13.1-1 will be updated
# ---> Package nvidia-container-toolkit.x86_64 0:1.13.5-1 will be an update
# ---> Package nvidia-container-toolkit-base.x86_64 0:1.13.1-1 will be updated
# ---> Package nvidia-container-toolkit-base.x86_64 0:1.13.5-1 will be an update
# ---> Package oniguruma.x86_64 0:5.9.6-1.amzn2.0.4 will be updated
# ---> Package oniguruma.x86_64 0:5.9.6-1.amzn2.0.5 will be an update
# ---> Package openldap.x86_64 0:2.4.44-25.amzn2.0.5 will be updated
# ---> Package openldap.x86_64 0:2.4.44-25.amzn2.0.7 will be an update
# ---> Package openssh.x86_64 0:7.4p1-22.amzn2.0.1 will be updated
# ---> Package openssh.x86_64 0:7.4p1-22.amzn2.0.3 will be an update
# ---> Package openssh-clients.x86_64 0:7.4p1-22.amzn2.0.1 will be updated
# ---> Package openssh-clients.x86_64 0:7.4p1-22.amzn2.0.3 will be an update
# ---> Package openssh-server.x86_64 0:7.4p1-22.amzn2.0.1 will be updated
# ---> Package openssh-server.x86_64 0:7.4p1-22.amzn2.0.3 will be an update
# ---> Package perl-HTTP-Tiny.noarch 0:0.033-3.amzn2 will be updated
# ---> Package perl-HTTP-Tiny.noarch 0:0.033-3.amzn2.0.1 will be an update
# ---> Package perl-Pod-Perldoc.noarch 0:3.20-4.amzn2 will be updated
# ---> Package perl-Pod-Perldoc.noarch 0:3.20-4.amzn2.0.1 will be an update
# ---> Package python-configobj.noarch 0:4.7.2-7.amzn2 will be updated
# ---> Package python-configobj.noarch 0:4.7.2-7.amzn2.0.1 will be an update
# ---> Package python-ipaddress.noarch 0:1.0.16-2.amzn2 will be updated
# ---> Package python-ipaddress.noarch 0:1.0.16-2.amzn2.0.2 will be an update
# ---> Package python-pillow.x86_64 0:2.0.0-23.gitd1c6db8.amzn2.0.5 will be updated
# ---> Package python-pillow.x86_64 0:2.0.0-23.gitd1c6db8.amzn2.0.7 will be an update
# ---> Package python-requests.noarch 0:2.6.0-7.amzn2 will be updated
# ---> Package python-requests.noarch 0:2.6.0-10.amzn2.0.1 will be an update
# ---> Package python2-rsa.noarch 0:3.4.1-1.amzn2.0.3 will be updated
# ---> Package python2-rsa.noarch 0:3.4.1-1.amzn2.0.4 will be an update
# ---> Package python3-pip.noarch 0:20.2.2-1.amzn2.0.3 will be updated
# ---> Package python3-pip.noarch 0:20.2.2-1.amzn2.0.4 will be an update
# ---> Package python3-setuptools.noarch 0:49.1.3-1.amzn2.0.2 will be updated
# ---> Package python3-setuptools.noarch 0:49.1.3-1.amzn2.0.3 will be an update
# ---> Package python38-setuptools.noarch 0:38.4.0-4.amzn2.0.1 will be updated
# ---> Package python38-setuptools.noarch 0:38.4.0-4.amzn2.0.2 will be an update
# ---> Package rdma-core.x86_64 0:41.0-2.amzn2.0.2 will be updated
# ---> Package rdma-core.x86_64 0:43.0-1.amzn2.0.2 will be an update
# ---> Package rdma-core-devel.x86_64 0:41.0-2.amzn2.0.2 will be updated
# ---> Package rdma-core-devel.x86_64 0:43.0-1.amzn2.0.2 will be an update
# ---> Package runc.x86_64 0:1.1.7-1.amzn2 will be updated
# ---> Package runc.x86_64 0:1.1.7-3.amzn2 will be an update
# ---> Package tcpdump.x86_64 14:4.9.2-4.amzn2.1 will be updated
# ---> Package tcpdump.x86_64 14:4.9.2-4.amzn2.1.0.1 will be an update
# ---> Package webkitgtk4.x86_64 0:2.38.5-3.amzn2.0.1 will be updated
# ---> Package webkitgtk4.x86_64 0:2.38.5-3.amzn2.0.3 will be an update
# ---> Package webkitgtk4-jsc.x86_64 0:2.38.5-3.amzn2.0.1 will be updated
# ---> Package webkitgtk4-jsc.x86_64 0:2.38.5-3.amzn2.0.3 will be an update
# ---> Package yajl.x86_64 0:2.0.4-4.amzn2.0.1 will be updated
# ---> Package yajl.x86_64 0:2.0.4-4.amzn2.0.3 will be an update
# --> Running transaction check
# ---> Package graphene.x86_64 0:1.10.6-2.amzn2.0.2 will be installed
# ---> Package libgudev1.x86_64 0:219-78.amzn2.0.22 will be installed
# ---> Package webrtc-audio-processing.x86_64 0:0.3-1.amzn2.0.1 will be installed
# --> Finished Dependency Resolution
# --> Running transaction check
# ---> Package kernel-devel.x86_64 0:5.10.109-104.500.amzn2 will be erased
# --> Finished Dependency Resolution
#
# Dependencies Resolved
#
# ================================================================================
#  Package             Arch   Version                  Repository            Size
# ================================================================================
# Installing:
#  grub2               x86_64 1:2.06-14.amzn2.0.1      amzn2-core            46 k
#      replacing  grub2.x86_64 1:2.06-9.amzn2.0.1
#  grub2-pc            x86_64 1:2.06-14.amzn2.0.1      amzn2-core            45 k
#      replacing  grub2.x86_64 1:2.06-9.amzn2.0.1
#  grub2-tools         x86_64 1:2.06-14.amzn2.0.1      amzn2-core           2.0 M
#      replacing  grub2-tools.x86_64 1:2.06-9.amzn2.0.1
#  grub2-tools-efi     x86_64 1:2.06-14.amzn2.0.1      amzn2-core           560 k
#      replacing  grub2-tools.x86_64 1:2.06-9.amzn2.0.1
#  grub2-tools-extra   x86_64 1:2.06-14.amzn2.0.1      amzn2-core           1.0 M
#      replacing  grub2-tools.x86_64 1:2.06-9.amzn2.0.1
#  grub2-tools-minimal x86_64 1:2.06-14.amzn2.0.1      amzn2-core           625 k
#      replacing  grub2-tools.x86_64 1:2.06-9.amzn2.0.1
#  kernel-devel        x86_64 5.10.186-179.751.amzn2   amzn2extra-kernel-5.10
#                                                                            16 M
# Updating:
#  amazon-cloudwatch-agent
#                      x86_64 1.300026.2-1.amzn2       amzn2-core            67 M
#  avahi-glib          x86_64 0.6.31-20.amzn2.0.2      amzn2-core            25 k
#  avahi-libs          x86_64 0.6.31-20.amzn2.0.2      amzn2-core            61 k
#  bind-export-libs    x86_64 32:9.11.4-26.P2.amzn2.13.1
#                                                      amzn2-core           1.1 M
#  bind-libs           x86_64 32:9.11.4-26.P2.amzn2.13.1
#                                                      amzn2-core           159 k
#  bind-libs-lite      x86_64 32:9.11.4-26.P2.amzn2.13.1
#                                                      amzn2-core           1.1 M
#  bind-license        noarch 32:9.11.4-26.P2.amzn2.13.1
#                                                      amzn2-core            92 k
#  bind-utils          x86_64 32:9.11.4-26.P2.amzn2.13.1
#                                                      amzn2-core           261 k
#  cloud-init          noarch 19.3-46.amzn2.0.1        amzn2-core           927 k
#  containerd          x86_64 1.6.19-1.amzn2.0.3       amzn2extra-docker     28 M
#  cups-libs           x86_64 1:1.6.3-51.amzn2.0.2     amzn2-core           356 k
#  elfutils            x86_64 0.176-2.amzn2.0.1        amzn2-core           303 k
#  elfutils-default-yama-scope
#                      noarch 0.176-2.amzn2.0.1        amzn2-core            33 k
#  elfutils-libelf     x86_64 0.176-2.amzn2.0.1        amzn2-core           194 k
#  elfutils-libelf-devel
#                      x86_64 0.176-2.amzn2.0.1        amzn2-core            40 k
#  elfutils-libs       x86_64 0.176-2.amzn2.0.1        amzn2-core           289 k
#  flac-libs           x86_64 1.3.0-5.amzn2.0.4        amzn2-core           165 k
#  fribidi             x86_64 1.0.2-1.amzn2.1.2        amzn2-core            80 k
#  fuse-overlayfs      x86_64 0.7.2-6.el7_8            centos-extras         54 k
#  glib2               x86_64 2.56.1-9.amzn2.0.6       amzn2-core           2.4 M
#  grub2-common        noarch 1:2.06-14.amzn2.0.1      amzn2-core           1.8 M
#  grub2-efi-x64-ec2   x86_64 1:2.06-14.amzn2.0.1      amzn2-core           286 k
#  grub2-pc-modules    noarch 1:2.06-14.amzn2.0.1      amzn2-core           943 k
#  gstreamer1          x86_64 1.18.4-4.amzn2.0.1       amzn2-core           1.3 M
#  gstreamer1-plugins-bad-free
#                      x86_64 1.18.4-5.amzn2.0.1       amzn2-core           2.0 M
#  gstreamer1-plugins-base
#                      x86_64 1.18.4-5.amzn2.0.3       amzn2-core           2.0 M
#  hibagent            noarch 1.1.0-6.amzn2            amzn2-core            18 k
#  ibacm               x86_64 43.0-1.amzn2.0.2         amzn2-core            84 k
#  infiniband-diags    x86_64 43.0-1.amzn2.0.2         amzn2-core           296 k
#  iputils             x86_64 20180629-11.amzn2.1.20160308
#                                                      amzn2-core           147 k
#  iso-codes           noarch 4.6.0-3.amzn2            amzn2-core           3.7 M
#  java-11-amazon-corretto-headless
#                      x86_64 1:11.0.20+8-1.amzn2      amzn2-core           165 M
#  kernel-headers      x86_64 5.10.186-179.751.amzn2   amzn2extra-kernel-5.10
#                                                                           1.4 M
#  kpatch-runtime      noarch 0.9.4-8.amzn2            amzn2-core            28 k
#  libX11              x86_64 1.6.7-3.amzn2.0.3        amzn2-core           606 k
#  libX11-common       noarch 1.6.7-3.amzn2.0.3        amzn2-core           165 k
#  libcap              x86_64 2.54-1.amzn2.0.2         amzn2-core            73 k
#  libgs               x86_64 9.25-5.amzn2.0.4         amzn2-core           4.5 M
#  libibumad           x86_64 43.0-1.amzn2.0.2         amzn2-core            26 k
#  libibverbs          x86_64 43.0-1.amzn2.0.2         amzn2-core           333 k
#  libibverbs-core     x86_64 43.0-1.amzn2.0.2         amzn2-core            85 k
#  libibverbs-utils    x86_64 43.0-1.amzn2.0.2         amzn2-core            62 k
#  libicu              x86_64 50.2-4.amzn2.0.1         amzn2-core           6.8 M
#  libjpeg-turbo       x86_64 2.0.90-2.amzn2.0.2       amzn2-core           171 k
#  libjpeg-turbo-devel x86_64 2.0.90-2.amzn2.0.2       amzn2-core           110 k
#  libnghttp2          x86_64 1.41.0-1.amzn2.0.1       amzn2-core            72 k
#  libnvidia-container-tools
#                      x86_64 1.13.5-1                 libnvidia-container   51 k
#  libnvidia-container1
#                      x86_64 1.13.5-1                 libnvidia-container  1.0 M
#  librdmacm           x86_64 43.0-1.amzn2.0.2         amzn2-core            69 k
#  librdmacm-utils     x86_64 43.0-1.amzn2.0.2         amzn2-core            86 k
#  libtiff             x86_64 4.0.3-35.amzn2.0.9       amzn2-core           174 k
#  libwayland-client   x86_64 1.17.0-1.amzn2.0.1       amzn2-core            34 k
#  libwayland-cursor   x86_64 1.17.0-1.amzn2.0.1       amzn2-core            22 k
#  libwayland-egl      x86_64 1.17.0-1.amzn2.0.1       amzn2-core            15 k
#  libwayland-server   x86_64 1.17.0-1.amzn2.0.1       amzn2-core            41 k
#  libzstd             x86_64 1.5.2-1.amzn2.0.1        amzn2-core           284 k
#  microcode_ctl       x86_64 2:2.1-47.amzn2.1.15      amzn2-core           627 k
#  ncurses             x86_64 6.0-8.20170212.amzn2.1.5 amzn2-core           351 k
#  ncurses-base        noarch 6.0-8.20170212.amzn2.1.5 amzn2-core            75 k
#  ncurses-libs        x86_64 6.0-8.20170212.amzn2.1.5 amzn2-core           306 k
#  nvidia-container-toolkit
#                      x86_64 1.13.5-1                 libnvidia-container  909 k
#  nvidia-container-toolkit-base
#                      x86_64 1.13.5-1                 libnvidia-container  3.1 M
#  oniguruma           x86_64 5.9.6-1.amzn2.0.5        amzn2-core           127 k
#  openldap            x86_64 2.4.44-25.amzn2.0.7      amzn2-core           351 k
#  openssh             x86_64 7.4p1-22.amzn2.0.3       amzn2-core           508 k
#  openssh-clients     x86_64 7.4p1-22.amzn2.0.3       amzn2-core           652 k
#  openssh-server      x86_64 7.4p1-22.amzn2.0.3       amzn2-core           457 k
#  perl-HTTP-Tiny      noarch 0.033-3.amzn2.0.1        amzn2-core            39 k
#  perl-Pod-Perldoc    noarch 3.20-4.amzn2.0.1         amzn2-core            87 k
#  python-configobj    noarch 4.7.2-7.amzn2.0.1        amzn2-core           117 k
#  python-ipaddress    noarch 1.0.16-2.amzn2.0.2       amzn2-core            35 k
#  python-pillow       x86_64 2.0.0-23.gitd1c6db8.amzn2.0.7
#                                                      amzn2-core           444 k
#  python-requests     noarch 2.6.0-10.amzn2.0.1       amzn2-core            95 k
#  python2-rsa         noarch 3.4.1-1.amzn2.0.4        amzn2-core            67 k
#  python3-pip         noarch 20.2.2-1.amzn2.0.4       amzn2-core           2.0 M
#  python3-setuptools  noarch 49.1.3-1.amzn2.0.3       amzn2-core           1.1 M
#  python38-setuptools noarch 38.4.0-4.amzn2.0.2       amzn2extra-python3.8 619 k
#  rdma-core           x86_64 43.0-1.amzn2.0.2         amzn2-core            55 k
#  rdma-core-devel     x86_64 43.0-1.amzn2.0.2         amzn2-core           377 k
#  runc                x86_64 1.1.7-3.amzn2            amzn2extra-docker    3.0 M
#  tcpdump             x86_64 14:4.9.2-4.amzn2.1.0.1   amzn2-core           424 k
#  webkitgtk4          x86_64 2.38.5-3.amzn2.0.3       amzn2-core            34 M
#  webkitgtk4-jsc      x86_64 2.38.5-3.amzn2.0.3       amzn2-core           7.2 M
#  yajl                x86_64 2.0.4-4.amzn2.0.3        amzn2-core            40 k
# Removing:
#  kernel-devel        x86_64 5.10.109-104.500.amzn2   @amzn2extra-kernel-5.10
#                                                                            76 M
# Installing for dependencies:
#  graphene            x86_64 1.10.6-2.amzn2.0.2       amzn2-core            59 k
#  libgudev1           x86_64 219-78.amzn2.0.22        amzn2-core           111 k
#  webrtc-audio-processing
#                      x86_64 0.3-1.amzn2.0.1          amzn2-core           282 k
#
# Transaction Summary
# ================================================================================
# Install   7 Packages (+3 Dependent packages)
# Upgrade  84 Packages
# Remove    1 Package
#
# Total download size: 375 M
# Downloading packages:
# Delta RPMs disabled because /usr/bin/applydeltarpm not installed.
# (1/94): avahi-glib-0.6.31-20.amzn2.0.2.x86_64.rpm          |  25 kB   00:00
# (2/94): avahi-libs-0.6.31-20.amzn2.0.2.x86_64.rpm          |  61 kB   00:00
# (3/94): bind-export-libs-9.11.4-26.P2.amzn2.13.1.x86_64.rp | 1.1 MB   00:00
# (4/94): bind-libs-9.11.4-26.P2.amzn2.13.1.x86_64.rpm       | 159 kB   00:00
# (5/94): bind-libs-lite-9.11.4-26.P2.amzn2.13.1.x86_64.rpm  | 1.1 MB   00:00
# (6/94): bind-license-9.11.4-26.P2.amzn2.13.1.noarch.rpm    |  92 kB   00:00
# (7/94): bind-utils-9.11.4-26.P2.amzn2.13.1.x86_64.rpm      | 261 kB   00:00
# (8/94): cloud-init-19.3-46.amzn2.0.1.noarch.rpm            | 927 kB   00:00
# (9/94): cups-libs-1.6.3-51.amzn2.0.2.x86_64.rpm            | 356 kB   00:00
# (10/94): elfutils-0.176-2.amzn2.0.1.x86_64.rpm             | 303 kB   00:00
# (11/94): elfutils-default-yama-scope-0.176-2.amzn2.0.1.noa |  33 kB   00:00
# (12/94): elfutils-libelf-0.176-2.amzn2.0.1.x86_64.rpm      | 194 kB   00:00
# (13/94): elfutils-libelf-devel-0.176-2.amzn2.0.1.x86_64.rp |  40 kB   00:00
# (14/94): elfutils-libs-0.176-2.amzn2.0.1.x86_64.rpm        | 289 kB   00:00
# (15/94): flac-libs-1.3.0-5.amzn2.0.4.x86_64.rpm            | 165 kB   00:00
# (16/94): fribidi-1.0.2-1.amzn2.1.2.x86_64.rpm              |  80 kB   00:00
# (17/94): glib2-2.56.1-9.amzn2.0.6.x86_64.rpm               | 2.4 MB   00:00
# (18/94): graphene-1.10.6-2.amzn2.0.2.x86_64.rpm            |  59 kB   00:00
# (19/94): grub2-2.06-14.amzn2.0.1.x86_64.rpm                |  46 kB   00:00
# (20/94): grub2-common-2.06-14.amzn2.0.1.noarch.rpm         | 1.8 MB   00:00
# (21/94): grub2-efi-x64-ec2-2.06-14.amzn2.0.1.x86_64.rpm    | 286 kB   00:00
# (22/94): grub2-pc-2.06-14.amzn2.0.1.x86_64.rpm             |  45 kB   00:00
# (23/94): grub2-pc-modules-2.06-14.amzn2.0.1.noarch.rpm     | 943 kB   00:00
# (24/94): containerd-1.6.19-1.amzn2.0.3.x86_64.rpm          |  28 MB   00:00
# (25/94): grub2-tools-2.06-14.amzn2.0.1.x86_64.rpm          | 2.0 MB   00:00
# (26/94): fuse-overlayfs-0.7.2-6.el7_8.x86_64.rpm           |  54 kB   00:00
# (27/94): grub2-tools-efi-2.06-14.amzn2.0.1.x86_64.rpm      | 560 kB   00:00
# (28/94): grub2-tools-extra-2.06-14.amzn2.0.1.x86_64.rpm    | 1.0 MB   00:00
# (29/94): grub2-tools-minimal-2.06-14.amzn2.0.1.x86_64.rpm  | 625 kB   00:00
# (30/94): gstreamer1-1.18.4-4.amzn2.0.1.x86_64.rpm          | 1.3 MB   00:00
# (31/94): amazon-cloudwatch-agent-1.300026.2-1.amzn2.x86_64 |  67 MB   00:00
# (32/94): gstreamer1-plugins-bad-free-1.18.4-5.amzn2.0.1.x8 | 2.0 MB   00:00
# (33/94): hibagent-1.1.0-6.amzn2.noarch.rpm                 |  18 kB   00:00
# (34/94): gstreamer1-plugins-base-1.18.4-5.amzn2.0.3.x86_64 | 2.0 MB   00:00
# (35/94): ibacm-43.0-1.amzn2.0.2.x86_64.rpm                 |  84 kB   00:00
# (36/94): infiniband-diags-43.0-1.amzn2.0.2.x86_64.rpm      | 296 kB   00:00
# (37/94): iputils-20180629-11.amzn2.1.20160308.x86_64.rpm   | 147 kB   00:00
# (38/94): iso-codes-4.6.0-3.amzn2.noarch.rpm                | 3.7 MB   00:00
# (39/94): kernel-headers-5.10.186-179.751.amzn2.x86_64.rpm  | 1.4 MB   00:00
# (40/94): kpatch-runtime-0.9.4-8.amzn2.noarch.rpm           |  28 kB   00:00
# (41/94): libX11-1.6.7-3.amzn2.0.3.x86_64.rpm               | 606 kB   00:00
# (42/94): libX11-common-1.6.7-3.amzn2.0.3.noarch.rpm        | 165 kB   00:00
# (43/94): libcap-2.54-1.amzn2.0.2.x86_64.rpm                |  73 kB   00:00
# (44/94): libgs-9.25-5.amzn2.0.4.x86_64.rpm                 | 4.5 MB   00:00
# (45/94): kernel-devel-5.10.186-179.751.amzn2.x86_64.rpm    |  16 MB   00:00
# (46/94): libgudev1-219-78.amzn2.0.22.x86_64.rpm            | 111 kB   00:00
# (47/94): libibumad-43.0-1.amzn2.0.2.x86_64.rpm             |  26 kB   00:00
# (48/94): libibverbs-43.0-1.amzn2.0.2.x86_64.rpm            | 333 kB   00:00
# (49/94): libibverbs-core-43.0-1.amzn2.0.2.x86_64.rpm       |  85 kB   00:00
# (50/94): libibverbs-utils-43.0-1.amzn2.0.2.x86_64.rpm      |  62 kB   00:00
# (51/94): libicu-50.2-4.amzn2.0.1.x86_64.rpm                | 6.8 MB   00:00
# (52/94): libjpeg-turbo-2.0.90-2.amzn2.0.2.x86_64.rpm       | 171 kB   00:00
# (53/94): libjpeg-turbo-devel-2.0.90-2.amzn2.0.2.x86_64.rpm | 110 kB   00:00
# (54/94): libnghttp2-1.41.0-1.amzn2.0.1.x86_64.rpm          |  72 kB   00:00
# (55/94): librdmacm-43.0-1.amzn2.0.2.x86_64.rpm             |  69 kB   00:00
# (56/94): librdmacm-utils-43.0-1.amzn2.0.2.x86_64.rpm       |  86 kB   00:00
# (57/94): libtiff-4.0.3-35.amzn2.0.9.x86_64.rpm             | 174 kB   00:00
# (58/94): libwayland-client-1.17.0-1.amzn2.0.1.x86_64.rpm   |  34 kB   00:00
# (59/94): libnvidia-container-tools-1.13.5-1.x86_64.rpm     |  51 kB   00:00
# (60/94): libwayland-cursor-1.17.0-1.amzn2.0.1.x86_64.rpm   |  22 kB   00:00
# (61/94): libwayland-egl-1.17.0-1.amzn2.0.1.x86_64.rpm      |  15 kB   00:00
# (62/94): libwayland-server-1.17.0-1.amzn2.0.1.x86_64.rpm   |  41 kB   00:00
# (63/94): libzstd-1.5.2-1.amzn2.0.1.x86_64.rpm              | 284 kB   00:00
# (64/94): libnvidia-container1-1.13.5-1.x86_64.rpm          | 1.0 MB   00:00
# (65/94): microcode_ctl-2.1-47.amzn2.1.15.x86_64.rpm        | 627 kB   00:00
# (66/94): ncurses-6.0-8.20170212.amzn2.1.5.x86_64.rpm       | 351 kB   00:00
# (67/94): ncurses-base-6.0-8.20170212.amzn2.1.5.noarch.rpm  |  75 kB   00:00
# (68/94): ncurses-libs-6.0-8.20170212.amzn2.1.5.x86_64.rpm  | 306 kB   00:00
# (69/94): oniguruma-5.9.6-1.amzn2.0.5.x86_64.rpm            | 127 kB   00:00
# (70/94): openldap-2.4.44-25.amzn2.0.7.x86_64.rpm           | 351 kB   00:00
# (71/94): openssh-7.4p1-22.amzn2.0.3.x86_64.rpm             | 508 kB   00:00
# (72/94): openssh-clients-7.4p1-22.amzn2.0.3.x86_64.rpm     | 652 kB   00:00
# (73/94): openssh-server-7.4p1-22.amzn2.0.3.x86_64.rpm      | 457 kB   00:00
# (74/94): perl-HTTP-Tiny-0.033-3.amzn2.0.1.noarch.rpm       |  39 kB   00:00
# (75/94): perl-Pod-Perldoc-3.20-4.amzn2.0.1.noarch.rpm      |  87 kB   00:00
# (76/94): python-configobj-4.7.2-7.amzn2.0.1.noarch.rpm     | 117 kB   00:00
# (77/94): python-ipaddress-1.0.16-2.amzn2.0.2.noarch.rpm    |  35 kB   00:00
# (78/94): nvidia-container-toolkit-1.13.5-1.x86_64.rpm      | 909 kB   00:00
# (79/94): python-pillow-2.0.0-23.gitd1c6db8.amzn2.0.7.x86_6 | 444 kB   00:00
# (80/94): python-requests-2.6.0-10.amzn2.0.1.noarch.rpm     |  95 kB   00:00
# (81/94): nvidia-container-toolkit-base-1.13.5-1.x86_64.rpm | 3.1 MB   00:00
# (82/94): python2-rsa-3.4.1-1.amzn2.0.4.noarch.rpm          |  67 kB   00:00
# (83/94): python3-pip-20.2.2-1.amzn2.0.4.noarch.rpm         | 2.0 MB   00:00
# (84/94): python3-setuptools-49.1.3-1.amzn2.0.3.noarch.rpm  | 1.1 MB   00:00
# (85/94): rdma-core-43.0-1.amzn2.0.2.x86_64.rpm             |  55 kB   00:00
# (86/94): python38-setuptools-38.4.0-4.amzn2.0.2.noarch.rpm | 619 kB   00:00
# (87/94): rdma-core-devel-43.0-1.amzn2.0.2.x86_64.rpm       | 377 kB   00:00
# (88/94): runc-1.1.7-3.amzn2.x86_64.rpm                     | 3.0 MB   00:00
# (89/94): tcpdump-4.9.2-4.amzn2.1.0.1.x86_64.rpm            | 424 kB   00:00
# (90/94): java-11-amazon-corretto-headless-11.0.20+8-1.amzn | 165 MB   00:02
# (91/94): webkitgtk4-2.38.5-3.amzn2.0.3.x86_64.rpm          |  34 MB   00:00
# (92/94): webkitgtk4-jsc-2.38.5-3.amzn2.0.3.x86_64.rpm      | 7.2 MB   00:00
# (93/94): yajl-2.0.4-4.amzn2.0.3.x86_64.rpm                 |  40 kB   00:00
# (94/94): webrtc-audio-processing-0.3-1.amzn2.0.1.x86_64.rp | 282 kB   00:00
# --------------------------------------------------------------------------------
# Total                                              109 MB/s | 375 MB  00:03
# Running transaction check
# Running transaction test
# Transaction test succeeded
# Running transaction
# Warning: RPMDB altered outside of yum.
#   Updating   : libcap-2.54-1.amzn2.0.2.x86_64                             1/183
#   Updating   : glib2-2.56.1-9.amzn2.0.6.x86_64                            2/183
#   Updating   : 1:grub2-common-2.06-14.amzn2.0.1.noarch                    3/183
#   Updating   : libjpeg-turbo-2.0.90-2.amzn2.0.2.x86_64                    4/183
#   Updating   : libibverbs-core-43.0-1.amzn2.0.2.x86_64                    5/183
#   Installing : 1:grub2-tools-minimal-2.06-14.amzn2.0.1.x86_64             6/183
#   Updating   : gstreamer1-1.18.4-4.amzn2.0.1.x86_64                       7/183
#   Updating   : elfutils-libelf-0.176-2.amzn2.0.1.x86_64                   8/183
#   Updating   : openldap-2.4.44-25.amzn2.0.7.x86_64                        9/183
#   Updating   : libibumad-43.0-1.amzn2.0.2.x86_64                         10/183
#   Updating   : openssh-7.4p1-22.amzn2.0.3.x86_64                         11/183
#   Updating   : librdmacm-43.0-1.amzn2.0.2.x86_64                         12/183
#   Updating   : libibverbs-43.0-1.amzn2.0.2.x86_64                        13/183
#   Updating   : libtiff-4.0.3-35.amzn2.0.9.x86_64                         14/183
#   Installing : 1:grub2-tools-2.06-14.amzn2.0.1.x86_64                    15/183
#   Updating   : libwayland-client-1.17.0-1.amzn2.0.1.x86_64               16/183
#   Updating   : avahi-libs-0.6.31-20.amzn2.0.2.x86_64                     17/183
#   Updating   : 32:bind-license-9.11.4-26.P2.amzn2.13.1.noarch            18/183
#   Updating   : 32:bind-libs-lite-9.11.4-26.P2.amzn2.13.1.x86_64          19/183
#   Updating   : 32:bind-libs-9.11.4-26.P2.amzn2.13.1.x86_64               20/183
#   Updating   : 1:cups-libs-1.6.3-51.amzn2.0.2.x86_64                     21/183
#   Updating   : infiniband-diags-43.0-1.amzn2.0.2.x86_64                  22/183
#   Updating   : elfutils-libelf-devel-0.176-2.amzn2.0.1.x86_64            23/183
#   Updating   : 1:grub2-pc-modules-2.06-14.amzn2.0.1.noarch               24/183
#   Installing : 1:grub2-pc-2.06-14.amzn2.0.1.x86_64                       25/183
#   Installing : graphene-1.10.6-2.amzn2.0.2.x86_64                        26/183
#   Updating   : libnvidia-container1-1.13.5-1.x86_64                      27/183
#   Updating   : libnvidia-container-tools-1.13.5-1.x86_64                 28/183
#   Updating   : libwayland-server-1.17.0-1.amzn2.0.1.x86_64               29/183
#   Updating   : iso-codes-4.6.0-3.amzn2.noarch                            30/183
#   Updating   : runc-1.1.7-3.amzn2.x86_64                                 31/183
#   Updating   : libX11-common-1.6.7-3.amzn2.0.3.noarch                    32/183
#   Updating   : libX11-1.6.7-3.amzn2.0.3.x86_64                           33/183
#   Updating   : gstreamer1-plugins-base-1.18.4-5.amzn2.0.3.x86_64         34/183
#   Updating   : python-configobj-4.7.2-7.amzn2.0.1.noarch                 35/183
#   Updating   : perl-HTTP-Tiny-0.033-3.amzn2.0.1.noarch                   36/183
#   Installing : webrtc-audio-processing-0.3-1.amzn2.0.1.x86_64            37/183
#   Updating   : nvidia-container-toolkit-base-1.13.5-1.x86_64             38/183
#   Updating   : libwayland-egl-1.17.0-1.amzn2.0.1.x86_64                  39/183
#   Updating   : webkitgtk4-jsc-2.38.5-3.amzn2.0.3.x86_64                  40/183
#   Updating   : webkitgtk4-2.38.5-3.amzn2.0.3.x86_64                      41/183
#   Updating   : python-requests-2.6.0-10.amzn2.0.1.noarch                 42/183
#   Updating   : ncurses-base-6.0-8.20170212.amzn2.1.5.noarch              43/183
#   Updating   : ncurses-libs-6.0-8.20170212.amzn2.1.5.x86_64              44/183
#   Updating   : python3-setuptools-49.1.3-1.amzn2.0.3.noarch              45/183
#   Updating   : elfutils-default-yama-scope-0.176-2.amzn2.0.1.noarch      46/183
#   Updating   : elfutils-libs-0.176-2.amzn2.0.1.x86_64                    47/183
#   Installing : libgudev1-219-78.amzn2.0.22.x86_64                        48/183
#   Updating   : gstreamer1-plugins-bad-free-1.18.4-5.amzn2.0.1.x86_64     49/183
#   Updating   : elfutils-0.176-2.amzn2.0.1.x86_64                         50/183
#   Updating   : python3-pip-20.2.2-1.amzn2.0.4.noarch                     51/183
#   Updating   : openssh-clients-7.4p1-22.amzn2.0.3.x86_64                 52/183
#   Updating   : ncurses-6.0-8.20170212.amzn2.1.5.x86_64                   53/183
#   Updating   : cloud-init-19.3-46.amzn2.0.1.noarch                       54/183
#   Updating   : nvidia-container-toolkit-1.13.5-1.x86_64                  55/183
#   Updating   : perl-Pod-Perldoc-3.20-4.amzn2.0.1.noarch                  56/183
#   Updating   : containerd-1.6.19-1.amzn2.0.3.x86_64                      57/183
#   Installing : 1:grub2-2.06-14.amzn2.0.1.x86_64                          58/183
#   Installing : kernel-devel-5.10.186-179.751.amzn2.x86_64                59/183
#   Updating   : rdma-core-devel-43.0-1.amzn2.0.2.x86_64                   60/183
#   Updating   : libgs-9.25-5.amzn2.0.4.x86_64                             61/183
#   Updating   : 32:bind-utils-9.11.4-26.P2.amzn2.13.1.x86_64              62/183
#   Updating   : avahi-glib-0.6.31-20.amzn2.0.2.x86_64                     63/183
#   Updating   : libwayland-cursor-1.17.0-1.amzn2.0.1.x86_64               64/183
#   Updating   : 1:grub2-efi-x64-ec2-2.06-14.amzn2.0.1.x86_64              65/183
#   Updating   : python-pillow-2.0.0-23.gitd1c6db8.amzn2.0.7.x86_64        66/183
#   Updating   : libibverbs-utils-43.0-1.amzn2.0.2.x86_64                  67/183
#   Updating   : librdmacm-utils-43.0-1.amzn2.0.2.x86_64                   68/183
#   Updating   : openssh-server-7.4p1-22.amzn2.0.3.x86_64                  69/183
#   Updating   : ibacm-43.0-1.amzn2.0.2.x86_64                             70/183
#   Installing : 1:grub2-tools-extra-2.06-14.amzn2.0.1.x86_64              71/183
#   Updating   : libjpeg-turbo-devel-2.0.90-2.amzn2.0.2.x86_64             72/183
#   Installing : 1:grub2-tools-efi-2.06-14.amzn2.0.1.x86_64                73/183
#   Updating   : iputils-20180629-11.amzn2.1.20160308.x86_64               74/183
#   Updating   : 32:bind-export-libs-9.11.4-26.P2.amzn2.13.1.x86_64        75/183
#   Updating   : libzstd-1.5.2-1.amzn2.0.1.x86_64                          76/183
#   Updating   : rdma-core-43.0-1.amzn2.0.2.x86_64                         77/183
#   Updating   : python2-rsa-3.4.1-1.amzn2.0.4.noarch                      78/183
#   Updating   : libnghttp2-1.41.0-1.amzn2.0.1.x86_64                      79/183
#   Updating   : kernel-headers-5.10.186-179.751.amzn2.x86_64              80/183
#   Updating   : libicu-50.2-4.amzn2.0.1.x86_64                            81/183
#   Updating   : hibagent-1.1.0-6.amzn2.noarch                             82/183
#   Updating   : oniguruma-5.9.6-1.amzn2.0.5.x86_64                        83/183
#   Updating   : python-ipaddress-1.0.16-2.amzn2.0.2.noarch                84/183
#   Updating   : 1:java-11-amazon-corretto-headless-11.0.20+8-1.amzn2.x    85/183
#   Updating   : kpatch-runtime-0.9.4-8.amzn2.noarch                       86/183
#   Updating   : flac-libs-1.3.0-5.amzn2.0.4.x86_64                        87/183
#   Updating   : python38-setuptools-38.4.0-4.amzn2.0.2.noarch             88/183
#   Updating   : fuse-overlayfs-0.7.2-6.el7_8.x86_64                       89/183
#   Updating   : fribidi-1.0.2-1.amzn2.1.2.x86_64                          90/183
# amazon-cloudwatch-agent is running
#
# ****** processing amazon-cloudwatch-agent ******
#   Updating   : amazon-cloudwatch-agent-1.300026.2-1.amzn2.x86_64         91/183
#   Updating   : 14:tcpdump-4.9.2-4.amzn2.1.0.1.x86_64                     92/183
#   Updating   : yajl-2.0.4-4.amzn2.0.3.x86_64                             93/183
#   Updating   : 2:microcode_ctl-2.1-47.amzn2.1.15.x86_64                  94/183
#   Cleanup    : rdma-core-devel-41.0-2.amzn2.0.2.x86_64                   95/183
#   Cleanup    : 1:grub2-efi-x64-ec2-2.06-9.amzn2.0.1.x86_64               96/183
#   Cleanup    : cloud-init-19.3-46.amzn2.noarch                           97/183
#   Cleanup    : python-pillow-2.0.0-23.gitd1c6db8.amzn2.0.5.x86_64        98/183
#   Cleanup    : libjpeg-turbo-devel-2.0.90-2.amzn2.0.1.x86_64             99/183
#   Cleanup    : kernel-devel-5.10.109-104.500.amzn2.x86_64               100/183
#   Cleanup    : elfutils-libelf-devel-0.176-2.amzn2.x86_64               101/183
#   Cleanup    : perl-Pod-Perldoc-3.20-4.amzn2.noarch                     102/183
#   Cleanup    : python3-pip-20.2.2-1.amzn2.0.3.noarch                    103/183
#   Cleanup    : 1:grub2-2.06-9.amzn2.0.1.x86_64                          104/183
#   Cleanup    : 1:grub2-pc-2.06-9.amzn2.0.1.x86_64                       105/183
#   Cleanup    : 1:grub2-pc-modules-2.06-9.amzn2.0.1.noarch               106/183
#   Cleanup    : python3-setuptools-49.1.3-1.amzn2.0.2.noarch             107/183
#   Cleanup    : perl-HTTP-Tiny-0.033-3.amzn2.noarch                      108/183
#   Cleanup    : python-configobj-4.7.2-7.amzn2.noarch                    109/183
#   Cleanup    : python-requests-2.6.0-7.amzn2.noarch                     110/183
#   Cleanup    : python2-rsa-3.4.1-1.amzn2.0.3.noarch                     111/183
#   Cleanup    : kernel-headers-5.10.179-171.711.amzn2.x86_64             112/183
#   Cleanup    : hibagent-1.1.0-5.amzn2.noarch                            113/183
#   Cleanup    : python-ipaddress-1.0.16-2.amzn2.noarch                   114/183
#   Cleanup    : 1:java-11-amazon-corretto-headless-11.0.19+7-1.amzn2.x   115/183
#   Cleanup    : kpatch-runtime-0.9.4-7.amzn2.noarch                      116/183
#   Cleanup    : python38-setuptools-38.4.0-4.amzn2.0.1.noarch            117/183
#   Cleanup    : amazon-cloudwatch-agent-1.247359.1b252618-1.x86_64       118/183
#   Cleanup    : webkitgtk4-jsc-2.38.5-3.amzn2.0.1.x86_64                 119/183
#   Cleanup    : webkitgtk4-2.38.5-3.amzn2.0.1.x86_64                     120/183
#   Cleanup    : gstreamer1-plugins-bad-free-1.10.4-3.amzn2.x86_64        121/183
#   Cleanup    : 32:bind-utils-9.11.4-26.P2.amzn2.13.x86_64               122/183
#   Cleanup    : 32:bind-libs-9.11.4-26.P2.amzn2.13.x86_64                123/183
#   Cleanup    : gstreamer1-plugins-base-1.10.4-2.amzn2.0.3.x86_64        124/183
#   Cleanup    : elfutils-0.176-2.amzn2.x86_64                            125/183
#   Cleanup    : openssh-clients-7.4p1-22.amzn2.0.1.x86_64                126/183
#   Cleanup    : libgs-9.25-5.amzn2.0.3.x86_64                            127/183
#   Cleanup    : elfutils-libs-0.176-2.amzn2.x86_64                       128/183
#   Cleanup    : 32:bind-libs-lite-9.11.4-26.P2.amzn2.13.x86_64           129/183
#   Cleanup    : ibacm-41.0-2.amzn2.0.2.x86_64                            130/183
#   Cleanup    : librdmacm-utils-41.0-2.amzn2.0.2.x86_64                  131/183
#   Cleanup    : libibverbs-utils-41.0-2.amzn2.0.2.x86_64                 132/183
#   Cleanup    : openssh-server-7.4p1-22.amzn2.0.1.x86_64                 133/183
#   Cleanup    : nvidia-container-toolkit-1.13.1-1.x86_64                 134/183
#   Cleanup    : libnvidia-container-tools-1.13.1-1.x86_64                135/183
#   Cleanup    : avahi-glib-0.6.31-20.amzn2.x86_64                        136/183
#   Cleanup    : libnvidia-container1-1.13.1-1.x86_64                     137/183
#   Cleanup    : openssh-7.4p1-22.amzn2.0.1.x86_64                        138/183
#   Cleanup    : libibverbs-41.0-2.amzn2.0.2.x86_64                       139/183
#   Cleanup    : librdmacm-41.0-2.amzn2.0.2.x86_64                        140/183
#   Cleanup    : 1:cups-libs-1.6.3-51.amzn2.x86_64                        141/183
#   Cleanup    : libtiff-4.0.3-35.amzn2.0.6.x86_64                        142/183
#   Cleanup    : libX11-1.6.7-3.amzn2.0.2.x86_64                          143/183
#   Cleanup    : gstreamer1-1.10.4-2.amzn2.0.2.x86_64                     144/183
#   Cleanup    : 1:grub2-tools-minimal-2.06-9.amzn2.0.1.x86_64            145/183
#   Cleanup    : 1:grub2-tools-2.06-9.amzn2.0.1.x86_64                    146/183
#   Cleanup    : infiniband-diags-41.0-2.amzn2.0.2.x86_64                 147/183
#   Cleanup    : libwayland-cursor-1.17.0-1.amzn2.x86_64                  148/183
#   Cleanup    : 32:bind-export-libs-9.11.4-26.P2.amzn2.13.x86_64         149/183
#   Cleanup    : containerd-1.6.19-1.amzn2.0.1.x86_64                     150/183
#   Cleanup    : ncurses-6.0-8.20170212.amzn2.1.4.x86_64                  151/183
#   Cleanup    : ncurses-libs-6.0-8.20170212.amzn2.1.4.x86_64             152/183
#   Cleanup    : iputils-20160308-10.amzn2.0.2.x86_64                     153/183
#   Cleanup    : ncurses-base-6.0-8.20170212.amzn2.1.4.noarch             154/183
#   Cleanup    : 1:grub2-common-2.06-9.amzn2.0.1.noarch                   155/183
#   Cleanup    : libX11-common-1.6.7-3.amzn2.0.2.noarch                   156/183
#   Cleanup    : 32:bind-license-9.11.4-26.P2.amzn2.13.noarch             157/183
#   Cleanup    : elfutils-default-yama-scope-0.176-2.amzn2.noarch         158/183
#   Cleanup    : iso-codes-3.46-2.amzn2.noarch                            159/183
#   Cleanup    : libcap-2.54-1.amzn2.0.1.x86_64                           160/183
#   Cleanup    : runc-1.1.7-1.amzn2.x86_64                                161/183
#   Cleanup    : libwayland-client-1.17.0-1.amzn2.x86_64                  162/183
#   Cleanup    : libibumad-41.0-2.amzn2.0.2.x86_64                        163/183
#   Cleanup    : glib2-2.56.1-9.amzn2.0.5.x86_64                          164/183
#   Cleanup    : libjpeg-turbo-2.0.90-2.amzn2.0.1.x86_64                  165/183
#   Cleanup    : avahi-libs-0.6.31-20.amzn2.x86_64                        166/183
#   Cleanup    : libibverbs-core-41.0-2.amzn2.0.2.x86_64                  167/183
#   Cleanup    : openldap-2.4.44-25.amzn2.0.5.x86_64                      168/183
#   Cleanup    : nvidia-container-toolkit-base-1.13.1-1.x86_64            169/183
#   Cleanup    : elfutils-libelf-0.176-2.amzn2.x86_64                     170/183
#   Cleanup    : libwayland-egl-1.17.0-1.amzn2.x86_64                     171/183
#   Cleanup    : libwayland-server-1.17.0-1.amzn2.x86_64                  172/183
#   Cleanup    : libzstd-1.5.2-1.amzn2.x86_64                             173/183
#   Cleanup    : rdma-core-41.0-2.amzn2.0.2.x86_64                        174/183
#   Cleanup    : libnghttp2-1.41.0-1.amzn2.x86_64                         175/183
#   Cleanup    : libicu-50.2-4.amzn2.x86_64                               176/183
#   Cleanup    : oniguruma-5.9.6-1.amzn2.0.4.x86_64                       177/183
#   Cleanup    : flac-libs-1.3.0-5.amzn2.0.2.x86_64                       178/183
#   Cleanup    : fuse-overlayfs-0.7.2-6.amzn2int.x86_64                   179/183
#   Cleanup    : fribidi-1.0.2-1.amzn2.1.1.x86_64                         180/183
#   Cleanup    : 14:tcpdump-4.9.2-4.amzn2.1.x86_64                        181/183
#   Cleanup    : yajl-2.0.4-4.amzn2.0.1.x86_64                            182/183
#   Cleanup    : 2:microcode_ctl-2.1-47.amzn2.0.15.x86_64                 183/183
#
# ****** processing amazon-cloudwatch-agent ******
#   Verifying  : 32:bind-license-9.11.4-26.P2.amzn2.13.1.noarch             1/183
#   Verifying  : 2:microcode_ctl-2.1-47.amzn2.1.15.x86_64                   2/183
#   Verifying  : elfutils-default-yama-scope-0.176-2.amzn2.0.1.noarch       3/183
#   Verifying  : yajl-2.0.4-4.amzn2.0.3.x86_64                              4/183
#   Verifying  : python-pillow-2.0.0-23.gitd1c6db8.amzn2.0.7.x86_64         5/183
#   Verifying  : 1:grub2-common-2.06-14.amzn2.0.1.noarch                    6/183
#   Verifying  : elfutils-libs-0.176-2.amzn2.0.1.x86_64                     7/183
#   Verifying  : python3-setuptools-49.1.3-1.amzn2.0.3.noarch               8/183
#   Verifying  : ncurses-base-6.0-8.20170212.amzn2.1.5.noarch               9/183
#   Verifying  : 14:tcpdump-4.9.2-4.amzn2.1.0.1.x86_64                     10/183
# ...
#   rdma-core.x86_64 0:43.0-1.amzn2.0.2
#   rdma-core-devel.x86_64 0:43.0-1.amzn2.0.2
#   runc.x86_64 0:1.1.7-3.amzn2
#   tcpdump.x86_64 14:4.9.2-4.amzn2.1.0.1
#   webkitgtk4.x86_64 0:2.38.5-3.amzn2.0.3
#   webkitgtk4-jsc.x86_64 0:2.38.5-3.amzn2.0.3
#   yajl.x86_64 0:2.0.4-4.amzn2.0.3
#
# Replaced:
#   grub2.x86_64 1:2.06-9.amzn2.0.1     grub2-tools.x86_64 1:2.06-9.amzn2.0.1
#
# Complete!
# Loaded plugins: dkms-build-requires, extras_suggestions, langpacks, priorities,
#               : update-motd, versionlock
# Existing lock /var/run/yum.pid: another copy is running as pid 5272.
# Another app is currently holding the yum lock; waiting for it to exit...
#   The other application is: yum
#     Memory :  88 M RSS (304 MB VSZ)
#     Started: Thu Aug 31 12:13:07 2023 - 00:01 ago
#     State  : Running, pid: 5272
# amzn2-core                                               | 3.7 kB     00:00
# amzn2extra-docker                                        | 3.0 kB     00:00
# amzn2extra-kernel-5.10                                   | 3.0 kB     00:00
# amzn2extra-python3.8                                     | 3.0 kB     00:00
# centos-extras                                            | 2.9 kB     00:00
# copr:copr.fedorainfracloud.org:vbatts:shadow-utils-newxi | 3.3 kB     00:00
# https://download.docker.com/linux/centos/2/x86_64/stable/repodata/repomd.xml: [Errno 14] HTTPS Error 404 - Not Found
# Trying other mirror.
# libnvidia-container/x86_64/signature                     |  833 B     00:00
# libnvidia-container/x86_64/signature                     | 2.1 kB     00:00 !!!
# neuron                                                   | 2.9 kB     00:00
# 61 packages excluded due to repository priority protections
# Package amazon-linux-extras-2.0.1-1.amzn2.noarch already installed and latest version
# Nothing to do
# Installing epel-release
# Loaded plugins: dkms-build-requires, extras_suggestions, langpacks, priorities,
#               : update-motd, versionlock
# Cleaning repos: amzn2-core amzn2extra-docker amzn2extra-epel
#               : amzn2extra-kernel-5.10 amzn2extra-python3.8 centos-extras
#               : copr:copr.fedorainfracloud.org:vbatts:shadow-utils-newxidmap
#               : docker-ce-stable libnvidia-container neuron
# 33 metadata files removed
# 15 sqlite files removed
# 0 metadata files removed
# Loaded plugins: dkms-build-requires, extras_suggestions, langpacks, priorities,
#               : update-motd, versionlock
# amzn2-core                                               | 3.7 kB     00:00
# amzn2extra-docker                                        | 3.0 kB     00:00
# amzn2extra-epel                                          | 3.0 kB     00:00
# amzn2extra-kernel-5.10                                   | 3.0 kB     00:00
# amzn2extra-python3.8                                     | 3.0 kB     00:00
# centos-extras                                            | 2.9 kB     00:00
# copr:copr.fedorainfracloud.org:vbatts:shadow-utils-newxi | 3.3 kB     00:00
# https://download.docker.com/linux/centos/2/x86_64/stable/repodata/repomd.xml: [Errno 14] HTTPS Error 404 - Not Found
# Trying other mirror.
# libnvidia-container/x86_64/signature                     |  833 B     00:00
# libnvidia-container/x86_64/signature                     | 2.1 kB     00:00 !!!
# neuron                                                   | 2.9 kB     00:00
# (1/15): amzn2-core/2/x86_64/group_gz                       | 2.5 kB   00:00
# (2/15): amzn2-core/2/x86_64/updateinfo                     | 677 kB   00:00
# (3/15): amzn2extra-epel/2/x86_64/primary_db                | 1.8 kB   00:00
# (4/15): amzn2extra-kernel-5.10/2/x86_64/updateinfo         |  35 kB   00:00
# (5/15): amzn2extra-docker/2/x86_64/updateinfo              |  12 kB   00:00
# (6/15): amzn2extra-epel/2/x86_64/updateinfo                |   76 B   00:00
# (7/15): amzn2extra-python3.8/2/x86_64/updateinfo           |   76 B   00:00
# (8/15): amzn2extra-python3.8/2/x86_64/primary_db           |  66 kB   00:00
# (9/15): amzn2extra-docker/2/x86_64/primary_db              | 108 kB   00:00
# (10/15): libnvidia-container/x86_64/primary                |  32 kB   00:00
# (11/15): copr:copr.fedorainfracloud.org:vbatts:shadow-util | 6.1 kB   00:00
# (12/15): neuron/primary_db                                 | 143 kB   00:00
# (13/15): amzn2extra-kernel-5.10/2/x86_64/primary_db        |  21 MB   00:00
# (14/15): centos-extras/primary_db                          | 250 kB   00:00
# (15/15): amzn2-core/2/x86_64/primary_db                    |  76 MB   00:01
# libnvidia-container                                                     211/211
# 62 packages excluded due to repository priority protections
# Resolving Dependencies
# --> Running transaction check
# ---> Package epel-release.noarch 0:7-11 will be installed
# --> Finished Dependency Resolution
#
# Dependencies Resolved
#
# ================================================================================
#  Package              Arch           Version      Repository               Size
# ================================================================================
# Installing:
#  epel-release         noarch         7-11         amzn2extra-epel          15 k
#
# Transaction Summary
# ================================================================================
# Install  1 Package
#
# Total download size: 15 k
# Installed size: 24 k
# Downloading packages:
# epel-release-7-11.noarch.rpm                               |  15 kB   00:00
# Running transaction check
# Running transaction test
# Transaction test succeeded
# Running transaction
#   Installing : epel-release-7-11.noarch                                     1/1
#   Verifying  : epel-release-7-11.noarch                                     1/1
#
# Installed:
#   epel-release.noarch 0:7-11
#
# Complete!
#   0  ansible2                 available    \
#         [ =2.4.2  =2.4.6  =2.8  =stable ]
#   2  httpd_modules            available    [ =1.0  =stable ]
#   3  memcached1.5             available    \
#         [ =1.5.1  =1.5.16  =1.5.17 ]
#   6  postgresql10             available    [ =10  =stable ]
#   9  R3.4                     available    [ =3.4.3  =stable ]
#  10  rust1                    available    \
#         [ =1.22.1  =1.26.0  =1.26.1  =1.27.2  =1.31.0  =1.38.0
#           =stable ]
#  18  libreoffice              available    \
#         [ =5.0.6.2_15  =5.3.6.1  =stable ]
#  19  gimp                     available    [ =2.8.22 ]
#  20  docker=latest            enabled      \
#         [ =17.12.1  =18.03.1  =18.06.1  =18.09.9  =stable ]
#  21  mate-desktop1.x          available    \
#         [ =1.19.0  =1.20.0  =stable ]
#  22  GraphicsMagick1.3        available    \
#         [ =1.3.29  =1.3.32  =1.3.34  =stable ]
#  23  tomcat8.5                available    \
#         [ =8.5.31  =8.5.32  =8.5.38  =8.5.40  =8.5.42  =8.5.50
#           =stable ]
#  24  epel=latest              enabled      [ =7.11  =stable ]
#  25  testing                  available    [ =1.0  =stable ]
#  26  ecs                      available    [ =stable ]
#  27  corretto8                available    \
#         [ =1.8.0_192  =1.8.0_202  =1.8.0_212  =1.8.0_222  =1.8.0_232
#           =1.8.0_242  =stable ]
#  30  squid4                   available    [ =4  =stable ]
#  32  lustre2.10               available    \
#         [ =2.10.5  =2.10.8  =stable ]
#  33  java-openjdk11           available    [ =11  =stable ]
#  34  lynis                    available    [ =stable ]
#  36  BCC                      available    [ =0.x  =stable ]
#  37  mono                     available    [ =5.x  =stable ]
#  38  nginx1                   available    [ =stable ]
#  40  mock                     available    [ =stable ]
#  41  postgresql11             available    [ =11  =stable ]
#  43  livepatch                available    [ =stable ]
#  44  python3.8=latest         enabled      [ =stable ]
#  45  haproxy2                 available    [ =stable ]
#  46  collectd                 available    [ =stable ]
#  47  aws-nitro-enclaves-cli   available    [ =stable ]
#  48  R4                       available    [ =stable ]
#   _  kernel-5.4               available    [ =stable ]
#  50  selinux-ng               available    [ =stable ]
#  51  php8.0                   available    [ =stable ]
#  52  tomcat9                  available    [ =stable ]
#  53  unbound1.13              available    [ =stable ]
#  54  mariadb10.5              available    [ =stable ]
#  55  kernel-5.10=latest       enabled      [ =stable ]
#  56  redis6                   available    [ =stable ]
#  57  ruby3.0                  available    [ =stable ]
#  58  postgresql12             available    [ =stable ]
#  59  postgresql13             available    [ =stable ]
#  60  mock2                    available    [ =stable ]
#  61  dnsmasq2.85              available    [ =stable ]
#  62  kernel-5.15              available    [ =stable ]
#  63  postgresql14             available    [ =stable ]
#  64  firefox                  available    [ =stable ]
#  65  lustre                   available    [ =stable ]
#  66  php8.1                   available    [ =stable ]
#  67  awscli1                  available    [ =stable ]
#  68  php8.2                   available    [ =stable ]
#  69  dnsmasq                  available    [ =stable ]
#  70  unbound1.17              available    [ =stable ]
#  71  golang1.19               available    [ =stable ]
#  72  collectd-python3         available    [ =stable ]
# Loaded plugins: dkms-build-requires, extras_suggestions, langpacks, priorities,
#               : update-motd, versionlock
# amzn2-core                                               | 3.7 kB     00:00
# amzn2extra-docker                                        | 3.0 kB     00:00
# amzn2extra-epel                                          | 3.0 kB     00:00
# amzn2extra-kernel-5.10                                   | 3.0 kB     00:00
# amzn2extra-python3.8                                     | 3.0 kB     00:00
# centos-extras                                            | 2.9 kB     00:00
# copr:copr.fedorainfracloud.org:vbatts:shadow-utils-newxi | 3.3 kB     00:00
# https://download.docker.com/linux/centos/2/x86_64/stable/repodata/repomd.xml: [Errno 14] HTTPS Error 404 - Not Found
# Trying other mirror.
# epel/x86_64/metalink                                     |  24 kB     00:00
# epel                                                     | 4.7 kB     00:00
# libnvidia-container/x86_64/signature                     |  833 B     00:00
# libnvidia-container/x86_64/signature                     | 2.1 kB     00:00 !!!
# neuron                                                   | 2.9 kB     00:00
# (1/3): epel/x86_64/group_gz                                |  99 kB   00:00
# (2/3): epel/x86_64/primary_db                              | 7.0 MB   00:00
# (3/3): epel/x86_64/updateinfo                              | 1.0 MB   00:00
# 286 packages excluded due to repository priority protections
# Resolving Dependencies
# --> Running transaction check
# ---> Package python-lockfile.noarch 1:0.9.1-4.amzn2 will be obsoleted
# ---> Package python-simplejson.x86_64 0:3.2.0-1.amzn2.0.2 will be obsoleted
# ---> Package python2-lockfile.noarch 1:0.11.0-17.el7 will be obsoleting
# ---> Package python2-simplejson.x86_64 0:3.11.1-1.el7 will be obsoleting
# --> Finished Dependency Resolution
#
# Dependencies Resolved
#
# ================================================================================
#  Package                  Arch         Version                 Repository  Size
# ================================================================================
# Installing:
#  python2-lockfile         noarch       1:0.11.0-17.el7         epel        29 k
#      replacing  python-lockfile.noarch 1:0.9.1-4.amzn2
#  python2-simplejson       x86_64       3.11.1-1.el7            epel       188 k
#      replacing  python-simplejson.x86_64 3.2.0-1.amzn2.0.2
#
# Transaction Summary
# ================================================================================
# Install  2 Packages
#
# Total download size: 218 k
# Downloading packages:
# warning: /var/cache/yum/x86_64/2/epel/packages/python2-lockfile-0.11.0-17.el7.noarch.rpm: Header V3 RSA/SHA256 Signature, key ID 352c64e5: NOKEY
# Public key for python2-lockfile-0.11.0-17.el7.noarch.rpm is not installed
# (1/2): python2-lockfile-0.11.0-17.el7.noarch.rpm           |  29 kB   00:00
# (2/2): python2-simplejson-3.11.1-1.el7.x86_64.rpm          | 188 kB   00:00
# --------------------------------------------------------------------------------
# Total                                              721 kB/s | 218 kB  00:00
# Retrieving key from file:///etc/pki/rpm-gpg/RPM-GPG-KEY-EPEL-7
# Importing GPG key 0x352C64E5:
#  Userid     : "Fedora EPEL (7) <epel@fedoraproject.org>"
#  Fingerprint: 91e9 7d7c 4a5e 96f1 7f3e 888f 6a2f aea2 352c 64e5
#  Package    : epel-release-7-11.noarch (@amzn2extra-epel)
#  From       : /etc/pki/rpm-gpg/RPM-GPG-KEY-EPEL-7
# Running transaction check
# Running transaction test
# Transaction test succeeded
# Running transaction
#   Installing : python2-simplejson-3.11.1-1.el7.x86_64                       1/4
#   Installing : 1:python2-lockfile-0.11.0-17.el7.noarch                      2/4
#   Erasing    : 1:python-lockfile-0.9.1-4.amzn2.noarch                       3/4
#   Erasing    : python-simplejson-3.2.0-1.amzn2.0.2.x86_64                   4/4
#   Verifying  : 1:python2-lockfile-0.11.0-17.el7.noarch                      1/4
#   Verifying  : python2-simplejson-3.11.1-1.el7.x86_64                       2/4
#   Verifying  : 1:python-lockfile-0.9.1-4.amzn2.noarch                       3/4
#   Verifying  : python-simplejson-3.2.0-1.amzn2.0.2.x86_64                   4/4
#
# Installed:
#   python2-lockfile.noarch 1:0.11.0-17.el7
#   python2-simplejson.x86_64 0:3.11.1-1.el7
#
# Replaced:
#   python-lockfile.noarch 1:0.9.1-4.amzn2
#   python-simplejson.x86_64 0:3.2.0-1.amzn2.0.2
#
# Complete!
# Loaded plugins: dkms-build-requires, extras_suggestions, langpacks, priorities,
#               : update-motd, versionlock
# https://download.docker.com/linux/centos/2/x86_64/stable/repodata/repomd.xml: [Errno 14] HTTPS Error 404 - Not Found
# Trying other mirror.
# neuron                                                   | 2.9 kB     00:00
# 286 packages excluded due to repository priority protections
# Package git-2.40.1-1.amzn2.0.1.x86_64 already installed and latest version
# Resolving Dependencies
# --> Running transaction check
# ---> Package git-lfs.x86_64 0:2.10.0-2.el7 will be installed
# --> Finished Dependency Resolution
#
# Dependencies Resolved
#
# ================================================================================
#  Package           Arch             Version                Repository      Size
# ================================================================================
# Installing:
#  git-lfs           x86_64           2.10.0-2.el7           epel           3.7 M
#
# Transaction Summary
# ================================================================================
# Install  1 Package
#
# Total download size: 3.7 M
# Installed size: 13 M
# Downloading packages:
# git-lfs-2.10.0-2.el7.x86_64.rpm                            | 3.7 MB   00:00
# Running transaction check
# Running transaction test
# Transaction test succeeded
# Running transaction
#   Installing : git-lfs-2.10.0-2.el7.x86_64                                  1/1
#   Verifying  : git-lfs-2.10.0-2.el7.x86_64                                  1/1
#
# Installed:
#   git-lfs.x86_64 0:2.10.0-2.el7
#
# Complete!

# %%
import sagemaker
import boto3
sess = sagemaker.Session()
# sagemaker session bucket -> used for uploading data, models and logs
# sagemaker will automatically create this bucket if it not exists
sagemaker_session_bucket=None
if sagemaker_session_bucket is None and sess is not None:
    # set to default bucket if a bucket name is not given
    sagemaker_session_bucket = sess.default_bucket()

try:
    role = sagemaker.get_execution_role()
except ValueError:
    iam = boto3.client('iam')
    role = iam.get_role(RoleName='sagemaker_execution_role')['Role']['Arn']

sess = sagemaker.Session(default_bucket=sagemaker_session_bucket)

print(f"sagemaker role arn: {role}")
print(f"sagemaker bucket: {sess.default_bucket()}")
print(f"sagemaker session region: {sess.boto_region_name}")
# Out:
# sagemaker role arn: arn:aws:iam::513489159680:role/NotebookStack-SmartSearchNotebookRole6F6BB12B-1HZYH25WILVZP
# sagemaker bucket: sagemaker-us-west-1-513489159680
# sagemaker session region: us-west-1

# %%
# !mkdir code

# %%
# %%writefile code/inference.py

from transformers import AutoTokenizer, AutoModel
import torch
import torch.nn.functional as F

# Helper: Mean Pooling - Take attention mask into account for correct averaging
def mean_pooling(model_output, attention_mask):
    token_embeddings = model_output[0] #First element of model_output contains all token embeddings
    input_mask_expanded = attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()
    return torch.sum(token_embeddings * input_mask_expanded, 1) / torch.clamp(input_mask_expanded.sum(1), min=1e-9)


def model_fn(model_dir):
  # Load model from HuggingFace Hub
  tokenizer = AutoTokenizer.from_pretrained(model_dir)
  model = AutoModel.from_pretrained(model_dir)
  return model, tokenizer

def predict_fn(data, model_and_tokenizer):
    # destruct model and tokenizer
    model, tokenizer = model_and_tokenizer

    # Tokenize sentences
    sentences = data.pop("inputs", data)
    encoded_input = tokenizer(sentences, padding=True, truncation=True, return_tensors='pt')

    # Compute token embeddings
    with torch.no_grad():
        model_output = model(**encoded_input)

    # Perform pooling
    sentence_embeddings = mean_pooling(model_output, encoded_input['attention_mask'])

    # Normalize embeddings
    sentence_embeddings = F.normalize(sentence_embeddings, p=2, dim=1)

    # return dictonary, which will be json serializable
    return sentence_embeddings.tolist()
# Out:
# Writing code/inference.py

# %%
repository = "BAAI/bge-large-en"
model_id=repository.split("/")[-1]
s3_location=f"s3://{sess.default_bucket()}/custom_inference/{model_id}/model.tar.gz"

# %%
# !git lfs install
# !git clone https://huggingface.co/$repository
# Out:
# Updated git hooks.
# Git LFS initialized.
# Cloning into 'bge-large-en'...
# remote: Enumerating objects: 57, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 57 (delta 1), reused 0 (delta 0), pack-reused 52
# Unpacking objects: 100% (57/57), 336.51 KiB | 5.18 MiB/s, done.
# Filtering content: 100% (2/2), 2.49 GiB | 85.54 MiB/s, done.

# %%
# !cp -r code/ $model_id/code/

# %%
# %cd $model_id
# !tar zcvf model.tar.gz *
# Out:
# /home/ec2-user/SageMaker/jupyter/guidance-for-custom-search-of-an-enterprise-knowledge-base-on-aws/Embedding_Model/bge-large-en
# 1_Pooling/
# 1_Pooling/config.json
# code/
# code/inference.py
# config.json
# config_sentence_transformers.json
# model.safetensors
# README.md
# sentence_bert_config.json
# special_tokens_map.json
# tokenizer_config.json
# tokenizer.json
# vocab.txt

# %%
# !aws s3 cp model.tar.gz $s3_location
# Out:
# upload: ./model.tar.gz to s3://sagemaker-us-west-1-513489159680/custom_inference/bge-large-en/model.tar.gz

# %%
import sagemaker
from sagemaker.huggingface.model import HuggingFaceModel

role = sagemaker.get_execution_role()

hub = {
	'HF_MODEL_ID':'BAAI/bge-large-en',
	'HF_TASK':'feature-extraction'
}

# create Hugging Face Model Class
huggingface_model = HuggingFaceModel(
   model_data=s3_location,       # path to your model and script
   role=role,                    # iam role with permissions to create an Endpoint
   transformers_version="4.12",  # transformers version used
   pytorch_version="1.9",        # pytorch version used
   py_version='py38',            # python version used
   env=hub,
)

endpoint_name = 'huggingface-inference-eb'
# instance_type = 'ml.g4dn.2xlarge'
instance_type = 'ml.g4dn.xlarge'
instance_count = 1

# deploy the endpoint endpoint
from sagemaker.serializers import JSONSerializer
from sagemaker.deserializers import JSONDeserializer
predictor = huggingface_model.deploy(
    endpoint_name = endpoint_name,
    instance_type = instance_type, 
    initial_instance_count = instance_count,
    serializer = JSONSerializer(),
    deserializer = JSONDeserializer()
)
# Out:
# --------

# %%
# Inference testing
import time
import sagemaker
from sagemaker.huggingface import HuggingFaceModel

hfp = sagemaker.huggingface.model.HuggingFacePredictor('pytorch-inference-bge-en-2')

embedding = hfp.predict({'inputs':['how to fly from beijing to shanghai','just test','just test2']})
# print(embedding)
print(len(embedding))
# Out:
# 3

# %%
# Inference testing
import time
import sagemaker
from sagemaker.huggingface import HuggingFaceModel

hfp = sagemaker.huggingface.model.HuggingFacePredictor('huggingface-inference-eb')

embedding = hfp.predict({'inputs':['测试一下']})[0][0]
print(embedding)
print(len(embedding))
# Out:
# [[0.8712589740753174, 0.5052060484886169, 0.2740682363510132, -0.5513402819633484, -0.07944260537624359, -1.3149785995483398, -0.793494701385498, 0.3268897235393524, -0.22465941309928894, 0.3542226552963257, 1.2372010946273804, 0.2902102470397949, 1.2085446119308472, -0.43506407737731934, -1.5119136571884155, 0.42192351818084717, 0.03407299146056175, 1.006209135055542, -0.35137292742729187, -0.0425872839987278, -0.15121668577194214, -0.1964746117591858, -1.4167044162750244, 1.1674302816390991, 0.5220500230789185, 0.03637400642037392, -0.4836733341217041, -0.1808638572692871, 0.3515581488609314, -0.5548102259635925, 1.1584266424179077, -0.03137408569455147, -0.23241683840751648, -0.5677440762519836, -0.09391452372074127, 0.34883055090904236, 0.9053539037704468, -0.3414804935455322, 0.04200834780931473, 1.1847137212753296, 0.4124067723751068, 0.2594391107559204, -0.4300248324871063, -0.2996428310871124, -0.18452507257461548, 0.876329779624939, 0.06690166145563126, 0.7313116192817688, -1.311432123184204, 0.4950956702232361, 0.5537236928939819, 6.704618453979492, -0.7282204627990723, 0.23557992279529572, -0.41470232605934143, 1.472485899925232, 0.2528579533100128, 0.25495392084121704, -0.1312102973461151, -0.2209843248128891, 1.0206313133239746, -0.4720824062824249, 0.2366805523633957, -0.4307038187980652, -0.30708837509155273, 0.050440214574337006, -0.830386757850647, -0.7832288146018982, 0.10706552863121033, -1.2998156547546387, 0.6145685911178589, -0.9718302488327026, -0.4082760214805603, 0.34203043580055237, 1.139776349067688, -0.07915940880775452, -0.10054270923137665, -0.09201613813638687, 0.6253873109817505, -1.1861388683319092, -0.23103952407836914, 0.3926762640476227, 0.2092399001121521, -0.6766840815544128, -1.2985502481460571, 0.8683897852897644, -0.46291592717170715, -0.5023369789123535, 0.26407313346862793, -0.16821366548538208, -1.3414872884750366, -0.4725911021232605, -0.23513048887252808, -0.37147924304008484, -1.0026190280914307, -0.5245263576507568, 0.5346083641052246, -0.9817683696746826, -0.5399976372718811, 1.4737880229949951, -0.07752568274736404, -0.30528196692466736, -0.8115940093994141, -0.7366069555282593, 0.9034596681594849, 0.24434241652488708, -1.492586612701416, 0.1232173889875412, 0.8168665170669556, -0.05211717262864113, 0.17430716753005981, -0.166417196393013, -0.5925791263580322, 0.3402833938598633, -1.0066944360733032, 0.23818032443523407, -0.5228254199028015, 0.013527506962418556, 1.4384243488311768, -0.07000470906496048, 0.061371855437755585, 0.1295892745256424, -0.7309132814407349, -0.6560322046279907, -0.3267471194267273, -0.17474423348903656, -0.0873759314417839, 0.29494374990463257, -0.24544113874435425, 1.2103488445281982, 0.03733817860484123, -0.011190411634743214, -0.8514584898948669, -0.48621875047683716, -0.37034690380096436, 0.7777926325798035, 0.05552215129137039, -0.8498233556747437, -0.8210511207580566, -0.5515267848968506, 1.1476130485534668, 0.41280031204223633, 0.09257297962903976, -0.46607011556625366, -0.2777654826641083, 0.04641260579228401, 0.2607206106185913, 0.16870281100273132, 0.5849412679672241, -0.5648077726364136, 0.44939059019088745, -0.09051584452390671, -0.13203072547912598, 0.35485145449638367, 0.1796657145023346, 0.36975616216659546, -0.2526414096355438, 0.9077863693237305, -1.2913187742233276, -0.46582433581352234, 0.06465628743171692, -0.16835342347621918, -0.18913212418556213, -0.27194976806640625, -0.26905375719070435, 0.29326775670051575, 0.33691173791885376, -0.3906955420970917, 0.28234922885894775, 0.4405539333820343, -0.14457398653030396, -0.5776341557502747, 0.0964767262339592, -0.021224403753876686, 0.47839072346687317, -0.41831734776496887, -0.6971287131309509, 0.2107510268688202, -0.21892592310905457, 0.12058621644973755, -1.7828266620635986, 0.44110697507858276, 0.5968543887138367, 0.17912566661834717, -0.5754764080047607, 0.5044442415237427, -0.8593969345092773, 1.3915127515792847, 0.8096351027488708, 0.22660675644874573, -1.384606122970581, -0.4991 ...
# 6
