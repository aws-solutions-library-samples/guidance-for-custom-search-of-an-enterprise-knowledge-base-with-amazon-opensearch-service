# %%
import os
import json
import traceback
import urllib.parse
import boto3
from datetime import datetime
import time
from smart_search import SmartSearchQA

# %%
EMBEDDING_ENDPOINT_NAME = "huggingface-inference-text2vec-base-chinese-v1"
host =  "search-smartsearch-5xgqh6z5jl2y5uszqwlr7nbyxe.us-west-2.es.amazonaws.com"
index =  "smart_search_qa_test_0522_1"
region = "us-west-2"
language = "chinese"
port = 443
bulk_size = 10000000

# retrieve secret manager value by key using boto3                                             
sm_client = boto3.client('secretsmanager')
master_user = sm_client.get_secret_value(SecretId='opensearch-master-user')['SecretString']
data= json.loads(master_user)
username = data.get('username')
password = data.get('password')
print("username:",username)
print("password:",password)

s3_res = boto3.resource('s3')
s3_cli = boto3.client('s3')
# Out:
# username: admin
# password: "PR|M/y9O1fj

# %%
search_qa = SmartSearchQA()
search_qa.init_cfg(index,
                 username,
                 password,
                 host,
                 port,
                 EMBEDDING_ENDPOINT_NAME,
                 region
                 )

local_file = "../test_file/iot-dg.pdf"

now1 = datetime.now()#begin time
loaded_files = search_qa.init_knowledge_vector(local_file,bulk_size,language)
now2 = datetime.now()#endtime
print("File import takes time:",now2-now1)
print("Complete the import of the following documents:", str(loaded_files))
# Out:
# begin to load pdf file
# language is chinese and file is pdf
# iot-dg.pdf Loaded successfully
# The file is loaded and the vector library is being generated
# ind  0 ,len: 20 text: ['AWS IoT Core 开发人员指南 ']
# embedding language: chinese
# append_num: 3
# text_append: AWS IoT Core 开发人员指南 ,AWS IoT Core 开发人员指南 AWS IoT Core: 开发人员指南 Copyright © 2023 Amazon Web Services, Inc. and/or its affiliates. All rights reserved. Amazon 的商标和商业外观不得用于任何非 Amazon 的商品或服务，也不得以任何可能引起客户混淆或者贬低或诋毁  Amazon 的方式使用。,所有非 Amazon 拥有的其它商标均为各自所有者的财产，这些所有者可能附属于 Amazon、与  Amazon 有关联或由 Amazon 赞助，也可能不是如此。
# ind  1 ,len: 201 text: ['AWS IoT Core 开发人员指南 AWS IoT Core: 开发人员指南 Copyright © 2023 Amazon Web Services, Inc. and/or its affiliates. All rights reserved. Amazon 的商标和商业外观不得用于任何非 Amazon 的商品或服务，也不得以任何可能引起客户混淆或者贬低或诋毁  Amazon 的方式使用。']
# embedding language: chinese
# append_num: 3
# text_append: AWS IoT Core 开发人员指南 AWS IoT Core: 开发人员指南 Copyright © 2023 Amazon Web Services, Inc. and/or its affiliates. All rights reserved. Amazon 的商标和商业外观不得用于任何非 Amazon 的商品或服务，也不得以任何可能引起客户混淆或者贬低或诋毁  Amazon 的方式使用。,所有非 Amazon 拥有的其它商标均为各自所有者的财产，这些所有者可能附属于 Amazon、与  Amazon 有关联或由 Amazon 赞助，也可能不是如此。,AWS IoT Core 开发人员指南 Table of Contents 什么是 AWS IoT？
# ind  2 ,len: 81 text: ['所有非 Amazon 拥有的其它商标均为各自所有者的财产，这些所有者可能附属于 Amazon、与  Amazon 有关联或由 Amazon 赞助，也可能不是如此。']
# embedding language: chinese
# append_num: 3
# text_append: 所有非 Amazon 拥有的其它商标均为各自所有者的财产，这些所有者可能附属于 Amazon、与  Amazon 有关联或由 Amazon 赞助，也可能不是如此。,AWS IoT Core 开发人员指南 Table of Contents 什么是 AWS IoT？, ..............................................................................................................................1 您的设备和应用程序如何访问 AWS IoT ..........................................................................................1 AWS IoT 能做的事情 ...................................................................................................................2 行业中的 IoT ......................................................................................................................2 家居自动化中的 IoT .............................................................................................................3 AWS IoT 的工作原理 ...................................................................................................................3 IoT 世界 ............................................................................................................................3 AWS IoT 服务概览 ..............................................................................................................5 AWS IoT Core 服务 ............................................................................................................8 了解有关 AWS IoT 的更多信息 ....................................................................................................10 AWS IoT 的培训资源 .........................................................................................................10 AWS IoT 资源和指南 .........................................................................................................11 社交媒体中的 AWS IoT ......................................................................................................11 AWS IoT Core 规则引擎使用的 AWS 服务 ............................................................................12 AWS IoT Core 支持的通信协议 ...........................................................................................12 AWS IoT 控制台中的新增功能 .....................................................................................................13 图例 ................................................................................................................................14 AWS IoT Core 入门 ..........................................................................................................................16 将第一个设备连接到 AWS IoT Core .............................................................................................16 设置您的AWS 账户 ....................................................................................................................17 注册一个 AWS 账户 ..........................................................................................................17 创建管理用户 ....................................................................................................................17 打开 AWS IoT 控制台 ........................................................................................................18 尝试 AWS IoT Core 交互式教程 ..................................................................................................18 连接 IoT 设备 ...................................................................................................................19 保存离线设备状态 ..............................................................................................................20 将设备数据路由到服务 .......................................................................................................20 试试 AWS IoT 快速连接 .............................................................................................................21 第 1 步 开始教程 ..............................................................................................................21 第 2 步 创建一个事物对象 ..................................................................................................23 第 3 步 将文件下载到您的设备 ............................................................................................25 第 4 步 运行示例 ......... ...
# ind  3 ,len: 50 text: ['AWS IoT Core 开发人员指南 Table of Contents 什么是 AWS IoT？']
# embedding language: chinese
# append_num: 3
# text_append: AWS IoT Core 开发人员指南 Table of Contents 什么是 AWS IoT？, ..............................................................................................................................1 您的设备和应用程序如何访问 AWS IoT ..........................................................................................1 AWS IoT 能做的事情 ...................................................................................................................2 行业中的 IoT ......................................................................................................................2 家居自动化中的 IoT .............................................................................................................3 AWS IoT 的工作原理 ...................................................................................................................3 IoT 世界 ............................................................................................................................3 AWS IoT 服务概览 ..............................................................................................................5 AWS IoT Core 服务 ............................................................................................................8 了解有关 AWS IoT 的更多信息 ....................................................................................................10 AWS IoT 的培训资源 .........................................................................................................10 AWS IoT 资源和指南 .........................................................................................................11 社交媒体中的 AWS IoT ......................................................................................................11 AWS IoT Core 规则引擎使用的 AWS 服务 ............................................................................12 AWS IoT Core 支持的通信协议 ...........................................................................................12 AWS IoT 控制台中的新增功能 .....................................................................................................13 图例 ................................................................................................................................14 AWS IoT Core 入门 ..........................................................................................................................16 将第一个设备连接到 AWS IoT Core .............................................................................................16 设置您的AWS 账户 ....................................................................................................................17 注册一个 AWS 账户 ..........................................................................................................17 创建管理用户 ....................................................................................................................17 打开 AWS IoT 控制台 ........................................................................................................18 尝试 AWS IoT Core 交互式教程 ..................................................................................................18 连接 IoT 设备 ...................................................................................................................19 保存离线设备状态 ..............................................................................................................20 将设备数据路由到服务 .......................................................................................................20 试试 AWS IoT 快速连接 .............................................................................................................21 第 1 步 开始教程 ..............................................................................................................21 第 2 步 创建一个事物对象 ..................................................................................................23 第 3 步 将文件下载到您的设备 ............................................................................................25 第 4 步 运行示例 ........................................................................................... ...
# ind  4 ,len: 4316 text: [' ..............................................................................................................................1 您的设备和应用程序如何访问 AWS IoT ..........................................................................................1 AWS IoT 能做的事情 ...................................................................................................................2 行业中的 IoT ......................................................................................................................2 家居自动化中的 IoT .............................................................................................................3 AWS IoT 的工作原理 ...................................................................................................................3 IoT 世界 ............................................................................................................................3 AWS IoT 服务概览 ..............................................................................................................5 AWS IoT Core 服务 ............................................................................................................8 了解有关 AWS IoT 的更多信息 ....................................................................................................10 AWS IoT 的培训资源 .........................................................................................................10 AWS IoT 资源和指南 .........................................................................................................11 社交媒体中的 AWS IoT ......................................................................................................11 AWS IoT Core 规则引擎使用的 AWS 服务 ............................................................................12 AWS IoT Core 支持的通信协议 ...........................................................................................12 AWS IoT 控制台中的新增功能 .....................................................................................................13 图例 ................................................................................................................................14 AWS IoT Core 入门 ..........................................................................................................................16 将第一个设备连接到 AWS IoT Core .............................................................................................16 设置您的AWS 账户 ....................................................................................................................17 注册一个 AWS 账户 ..........................................................................................................17 创建管理用户 ....................................................................................................................17 打开 AWS IoT 控制台 ........................................................................................................18 尝试 AWS IoT Core 交互式教程 ..................................................................................................18 连接 IoT 设备 ...................................................................................................................19 保存离线设备状态 ..............................................................................................................20 将设备数据路由到服务 .......................................................................................................20 试试 AWS IoT 快速连接 .............................................................................................................21 第 1 步 开始教程 ..............................................................................................................21 第 2 步 创建一个事物对象 ..................................................................................................23 第 3 步 将文件下载到您的设备 ............................................................................................25 第 4 步 运行示例 ..............................................................................................................27 步骤 5：进一步探索 ..... ...
# Embedding Error: Error raised by inference endpoint: An error occurred (ModelError) when calling the InvokeEndpoint operation: Received client error (400) from primary with message "{
#   "code": 400,
#   "type": "InternalServerException",
#   "message": "The size of tensor a (4044) must match the size of tensor b (512) at non-singleton dimension 1"
# }
# ". See https://us-west-2.console.aws.amazon.com/cloudwatch/home?region=us-west-2#logEventViewer:group=/aws/sagemaker/Endpoints/huggingface-inference-text2vec-base-chinese-v1 in account 513489159680 for more information.
# ind  5 ,len: 2287 text: [' ....................................................................................................35 创建 AWS IoT 资源 ...........................................................................................................35 配置您的设备 ....................................................................................................................38 使用 AWS IoT MQTT 客户端查看 MQTT 消息 ...............................................................................63 查看 MQTT 客户端中的 MQTT 消息 .....................................................................................63 从 MQTT 客户端发布 MQTT 消息 ........................................................................................65 在 MQTT 客户端中测试共享订阅 .........................................................................................66 连接到 AWS IoT Core .......................................................................................................................68 AWS IoT Core - 控制面板终端节点 ...............................................................................................68 AWS IoT 设备终端节点 ..............................................................................................................69 AWS IoT Core用于 LoRa WAN 网关和设备 ...................................................................................70 连接到 AWS IoT Core 服务终端节点 ............................................................................................70 AWS CLI for AWS IoT Core ...............................................................................................70 AWS SDK ........................................................................................................................71 AWSMobile SDK ...............................................................................................................75 AWS IoT Core 服务的 REST API ........................................................................................75 将设备连接到 AWS IoT ..............................................................................................................76 AWS IoT 设备数据和服务终端节点 .......................................................................................76 AWS IoT Device SDK .......................................................................................................77 iii']
# Embedding Error: Error raised by inference endpoint: An error occurred (ModelError) when calling the InvokeEndpoint operation: Received client error (400) from primary with message "{
#   "code": 400,
#   "type": "InternalServerException",
#   "message": "The size of tensor a (2069) must match the size of tensor b (512) at non-singleton dimension 1"
# }
# ". See https://us-west-2.console.aws.amazon.com/cloudwatch/home?region=us-west-2#logEventViewer:group=/aws/sagemaker/Endpoints/huggingface-inference-text2vec-base-chinese-v1 in account 513489159680 for more information.
# ind  6 ,len: 6804 text: ['AWS IoT Core 开发人员指南 设备通信协议 ....................................................................................................................79 MQTT 主题 ......................................................................................................................99 可配置的终端节点 ............................................................................................................113 连接到 AWS IoT FIPS 终端节点 ................................................................................................120 AWS IoT Core - 控制面板终端节点 .....................................................................................120 AWS IoT Core - 数据层面终端节点 .....................................................................................121 AWS IoT Device Management - 任务数据终端节点 ...............................................................121 AWS IoT Device Management - Fleet Hub 终端节点 .............................................................121 AWS IoT Device Management - 安全隧道终端节点 ...............................................................121 AWS IoT 教程 ................................................................................................................................122 用 AWS IoT Device Client 构建演示 ...........................................................................................122 使用 AWS IoT Device Client 构建演示的先决条件 .................................................................122 AWS IoT Device Client 的设备准备 ....................................................................................124 安装并配置 AWS IoTDevice Client .....................................................................................133 演示 MQTT 消息与 AWS IoTDevice Client 通信 ...................................................................141 使用 AWS IoTDevice Client 演示远程操作（任务） ...............................................................153 清理 ..............................................................................................................................162 使用 AWS IoT设备开发工具包构建解决方案 .................................................................................168 开始使用 AWS IoT设备开发工具包构建解决方案 ...................................................................168 使用 AWS IoT设备开发工具包将设备连接到 AWS IoT Core ....................................................168 创建将设备数据路由到其他服务的 AWS IoT规则 ...................................................................183 在设备处于离线状态时使用设备影子保持设备状态 .................................................................209 为 AWS IoT Core创建自定义授权方 ...................................................................................227 使用 AWS IoT和 Raspberry Pi 监控土壤含水量 ....................................................................238 使用 AWS IoT 管理设备 ...................................................................................................................247 如何使用注册表管理事物 ...........................................................................................................247 创建事物 ........................................................................................................................247 列出事物 ........................................................................................................................248 描述事物 ........................................................................................................................249 更新事物 ........................................................................................................................250 删除事物 ........................................................................................................................250 将委托人附加到事物 .........................................................................................................250 将委托人与事物分离 .........................................................................................................250 事物类型 ........................................................................................................................ ...
# Embedding Error: Error raised by inference endpoint: An error occurred (ModelError) when calling the InvokeEndpoint operation: Received client error (400) from primary with message "{
#   "code": 400,
#   "type": "InternalServerException",
#   "message": "The size of tensor a (6281) must match the size of tensor b (512) at non-singleton dimension 1"
# }
# ". See https://us-west-2.console.aws.amazon.com/cloudwatch/home?region=us-west-2#logEventViewer:group=/aws/sagemaker/Endpoints/huggingface-inference-text2vec-base-chinese-v1 in account 513489159680 for more information.
# ind  7 ,len: 7027 text: ['AWS IoT Core 开发人员指南 创建动态事物组 ...............................................................................................................263 描述动态事物组 ...............................................................................................................263 更新动态事物组 ...............................................................................................................264 删除动态事物组 ...............................................................................................................264 限制和冲突 .....................................................................................................................265 给您的 AWS IoT 资源加标签 .............................................................................................................267 有关标签的基本知识 .................................................................................................................267 标签限制 ........................................................................................................................268 在 IAM 策略中使用标签 ............................................................................................................268 账单组 ...................................................................................................................................269 查看成本分配和使用率数据 ................................................................................................270 安全性 ...........................................................................................................................................271 AWS IoT 中的安全性 ...............................................................................................................271 身份验证 ................................................................................................................................272 AWS 培训和认证 .............................................................................................................272 X.509 证书概览 ...............................................................................................................272 服务器身份验证 ...............................................................................................................272 客户端身份验证 ...............................................................................................................275 自定义身份验证和授权 ......................................................................................................295 Authorization ..........................................................................................................................306 AWS 培训和认证 .............................................................................................................307 AWS IoT Core 策略 .........................................................................................................307 使用 AWS IoT Core 凭证提供程序授予直接调用AWS服务的权限 .............................................348 通过 IAM 跨账户访问 .......................................................................................................352 数据保护 ................................................................................................................................353 AWS IoT 中的数据加密 ....................................................................................................354 AWS IoT Core 中的传输安全 ............................................................................................354 数据加密 ........................................................................................................................357 身份和访问管理 .......................................................................................................................358 受众 ..............................................................................................................................358 使用 IAM 身份进行身份验证 ..............................................................................................358 使用策略管理访问 ............................................................... ...
# Embedding Error: Error raised by inference endpoint: An error occurred (ModelError) when calling the InvokeEndpoint operation: Received client error (400) from primary with message "{
#   "code": 400,
#   "type": "InternalServerException",
#   "message": "The size of tensor a (6598) must match the size of tensor b (512) at non-singleton dimension 1"
# }
# ". See https://us-west-2.console.aws.amazon.com/cloudwatch/home?region=us-west-2#logEventViewer:group=/aws/sagemaker/Endpoints/huggingface-inference-text2vec-base-chinese-v1 in account 513489159680 for more information.
# ind  8 ,len: 7143 text: ['AWS IoT Core 开发人员指南 针对 Device Advisor 防范跨服务混淆代理 ............................................................................402 AWS 培训和认证 .....................................................................................................................402 监控 AWS IoT ................................................................................................................................403 配置 AWS IoT 日志记录 ...........................................................................................................403 配置日志记录角色和策略 ...................................................................................................404 在 AWS IoT（控制台）中配置默认日志记录 .........................................................................405 在 AWS IoT 中配置默认日志记录 (CLI) ...............................................................................406 在 AWS IoT 中配置资源特定的日志记录 (CLI) ......................................................................407 日志级别 ........................................................................................................................409 使用 Amazon 监控AWS IoT告警和指标 CloudWatch .....................................................................409 使用 AWS IoT 指标 .........................................................................................................410 在中创建 CloudWatch 警报AWS IoT ...................................................................................410 AWS IoT 指标和维度 .......................................................................................................413 AWS IoT使用 CloudWatch 日志进行监控 ....................................................................................422 在 CloudWatch 控制台中查看AWS IoT日志 .........................................................................422 CloudWatch AWS IoT日志条目 ..........................................................................................422 将设备端日志上载到 Amazon CloudWatch ...................................................................................443 工作原理 ........................................................................................................................443 使用 AWS IoT 规则上载设备端日志 ....................................................................................444 使用 AWS CloudTrail 记录 AWS IoT API 调用 .............................................................................451 AWS IoT中的信息 CloudTrail ............................................................................................451 了解 AWS IoT 日志文件条目 .............................................................................................451 规则 ..............................................................................................................................................453 向 AWS IoT 规则授予所需的访问权限 .........................................................................................454 传递角色权限 ..........................................................................................................................455 创建 AWS IoT 规则 .................................................................................................................456 查看您的规则 ..........................................................................................................................459 删除规则 ................................................................................................................................459 AWS IoT 规则操作 ..................................................................................................................460 Apache Kafka .................................................................................................................461 CloudWatch 警报 ............................................................................................................468 CloudWatch 日志 ............................................................................................................469 CloudWatch 指标 ...................................................... ...
# Embedding Error: Error raised by inference endpoint: An error occurred (ModelError) when calling the InvokeEndpoint operation: Received client error (400) from primary with message "{
#   "code": 400,
#   "type": "InternalServerException",
#   "message": "The size of tensor a (6529) must match the size of tensor b (512) at non-singleton dimension 1"
# }
# ". See https://us-west-2.console.aws.amazon.com/cloudwatch/home?region=us-west-2#logEventViewer:group=/aws/sagemaker/Endpoints/huggingface-inference-text2vec-base-chinese-v1 in account 513489159680 for more information.
# ind  9 ,len: 7080 text: ['AWS IoT Core 开发人员指南 Amazon S3 的跨账户设置 .................................................................................................535 AWS Lambda 跨账户设置 .................................................................................................536 错误处理（错误操作） ..............................................................................................................538 错误操作消息格式 ............................................................................................................538 错误操作示例 ..................................................................................................................539 借助基本摄取功能，降低消息收发成本 ........................................................................................539 使用基本摄取功能 ............................................................................................................540 AWS IoT SQL 参考 .................................................................................................................540 SELECT 子句 .................................................................................................................541 FROM 子句 ....................................................................................................................542 WHERE 子句 ..................................................................................................................543 数据类型 ........................................................................................................................544 运算符 ...........................................................................................................................547 函数 ..............................................................................................................................552 文本 ..............................................................................................................................593 Case 语句 ......................................................................................................................593 JSON 扩展 .....................................................................................................................594 替换模板 ........................................................................................................................596 嵌套对象查询 ..................................................................................................................597 二进制负载 .....................................................................................................................598 SQL 版本 .......................................................................................................................602 Device Shadow 服务 .......................................................................................................................604 使用影子 ................................................................................................................................604 选择使用命名或未命名的影子 .............................................................................................604 访问影子 ........................................................................................................................604 在设备、应用程序和其它云服务中使用影子 ..........................................................................605 消息顺序 ........................................................................................................................605 修剪影子消息 ..................................................................................................................606 在设备中使用影子 ....................................................................................................................607 首次连接到 AWS IoT 时初始化设备 ....................................................................................608 在设备连接到 AWS IoT 后处理消息 ....................................................................................609 在设备重新连接到 AWS IoT 时处理消息 ................................................................... ...
# Embedding Error: Error raised by inference endpoint: An error occurred (ModelError) when calling the InvokeEndpoint operation: Received client error (400) from primary with message "{
#   "code": 400,
#   "type": "InternalServerException",
#   "message": "The size of tensor a (6690) must match the size of tensor b (512) at non-singleton dimension 1"
# }
# ". See https://us-west-2.console.aws.amazon.com/cloudwatch/home?region=us-west-2#logEventViewer:group=/aws/sagemaker/Endpoints/huggingface-inference-text2vec-base-chinese-v1 in account 513489159680 for more information.
# ind  10 ,len: 2739 text: ['AWS IoT Core 开发人员指南 /get/rejected ....................................................................................................................632 /update ..........................................................................................................................633 /update/delta ...................................................................................................................634 /update/accepted .............................................................................................................635 /update/documents ..........................................................................................................635 /update/rejected ..............................................................................................................636 /delete ...........................................................................................................................636 /delete/accepted ..............................................................................................................637 /delete/rejected ...............................................................................................................638 Device Shadow 服务文档 .........................................................................................................638 影子文档示例 ..................................................................................................................639 文档属性 ........................................................................................................................643 增量状态 ........................................................................................................................643 对影子文档进行版本控制 ...................................................................................................645 影子文档中的客户端令牌 ...................................................................................................645 空影子文档属性 ...............................................................................................................645 影子文档中的数组值 .........................................................................................................646 Device Shadow 错误消息 .........................................................................................................646 任务 ..............................................................................................................................................648 访问 AWS IoT 任务 .................................................................................................................648 AWS IoT Jobs 区域和终端节点 ..................................................................................................648 AWS IoT Jobs 是什么？']
# Embedding Error: Error raised by inference endpoint: An error occurred (ModelError) when calling the InvokeEndpoint operation: Received client error (400) from primary with message "{
#   "code": 400,
#   "type": "InternalServerException",
#   "message": "The size of tensor a (2542) must match the size of tensor b (512) at non-singleton dimension 1"
# }
# ". See https://us-west-2.console.aws.amazon.com/cloudwatch/home?region=us-west-2#logEventViewer:group=/aws/sagemaker/Endpoints/huggingface-inference-text2vec-base-chinese-v1 in account 513489159680 for more information.
# ind  11 ,len: 3826 text: [' ...........................................................................................................648 任务关键概念 ..................................................................................................................649 任务和任务执行状态 .........................................................................................................651 管理任务 ................................................................................................................................654 任务的代码签名 ...............................................................................................................654 任务文档 ........................................................................................................................654 预签名 URL ....................................................................................................................655 使用控制台创建和管理任务 ................................................................................................656 使用 CLI 创建和管理任务 ..................................................................................................658 任务模板 ................................................................................................................................665 自定义和 AWS 托管模板 ...................................................................................................665 使用 AWS 托管式模板 ......................................................................................................665 创建自定义任务模板 .........................................................................................................678 任务配置 ................................................................................................................................683 任务配置的工作原理 .........................................................................................................683 指定其他配置 ..................................................................................................................691 设备和任务 .............................................................................................................................696 对设备进行编程以使用任务 ................................................................................................698 设备工作流程 ..................................................................................................................698 任务流 ...........................................................................................................................699 任务通知 ........................................................................................................................702 AWS IoT 任务 API 操作 ...........................................................................................................708 任务管理和控制 API 以及数据类型 .....................................................................................709 任务设备 MQTT 和 HTTPS API 操作以及数据类型 ................................................................722 保护 Jobs 的用户和设备 ...........................................................................................................732 AWS IoT Jobs 所需的策略类型 ..........................................................................................732 向 Jobs 用户和云服务授权 ................................................................................................733 授权设备使用任务 ............................................................................................................739 任务限制 ................................................................................................................................741 活动和并发任务限制 .........................................................................................................741 AWS IoT 安全隧道 ..........................................................................................................................743 什么是安全隧道？']
# Embedding Error: Error raised by inference endpoint: An error occurred (ModelError) when calling the InvokeEndpoint operation: Received client error (400) from primary with message "{
#   "code": 400,
#   "type": "InternalServerException",
#   "message": "The size of tensor a (3667) must match the size of tensor b (512) at non-singleton dimension 1"
# }
# ". See https://us-west-2.console.aws.amazon.com/cloudwatch/home?region=us-west-2#logEventViewer:group=/aws/sagemaker/Endpoints/huggingface-inference-text2vec-base-chinese-v1 in account 513489159680 for more information.
# ind  12 ,len: 617 text: [' ....................................................................................................................743 安全隧道概念 ..................................................................................................................743 安全隧道的工作原理 .........................................................................................................744 安全隧道生命周期 ............................................................................................................744 AWS IoT 安全隧道教程 ............................................................................................................745 viii']
# Embedding Error: Error raised by inference endpoint: An error occurred (ModelError) when calling the InvokeEndpoint operation: Received client error (400) from primary with message "{
#   "code": 400,
#   "type": "InternalServerException",
#   "message": "The size of tensor a (596) must match the size of tensor b (512) at non-singleton dimension 1"
# }
# ". See https://us-west-2.console.aws.amazon.com/cloudwatch/home?region=us-west-2#logEventViewer:group=/aws/sagemaker/Endpoints/huggingface-inference-text2vec-base-chinese-v1 in account 513489159680 for more information.
# ...
# embedding language: chinese
# append_num: 3
# text_append:  按照 使用 AWS IoT MQTT 客户端查看 MQTT 消息  (p. 63) 中的说明执行操作，配置控制台以订阅 消息，该消息应带有 curl 命令中所用的名为 topic  的主题，或使用 # 通配符主题筛选条件。, 5.测试命令。, 在 AWS IoT 控制台的测试客户端中监控主题时，请转到客户端并发出您在步骤 3 中创建的 curl 命 令行。
# ind  1595 ,len: 8 text: [' 5.测试命令。']
# embedding language: chinese
# append_num: 3
# text_append:  5.测试命令。, 在 AWS IoT 控制台的测试客户端中监控主题时，请转到客户端并发出您在步骤 3 中创建的 curl 命 令行。,控制台中应显示客户端的消息。
# ind  1596 ,len: 58 text: [' 在 AWS IoT 控制台的测试客户端中监控主题时，请转到客户端并发出您在步骤 3 中创建的 curl 命 令行。']
# embedding language: chinese
# append_num: 3
# text_append:  在 AWS IoT 控制台的测试客户端中监控主题时，请转到客户端并发出您在步骤 3 中创建的 curl 命 令行。,控制台中应显示客户端的消息。, MQTT 主题 MQTT 主题将标识 AWS IoT 消息。
# ind  1597 ,len: 14 text: ['控制台中应显示客户端的消息。']
# embedding language: chinese
# append_num: 3
# text_append: 控制台中应显示客户端的消息。, MQTT 主题 MQTT 主题将标识 AWS IoT 消息。,AWS IoT 客户端通过向消息提供主题名称来标识其发布的消息。
# ind  1598 ,len: 31 text: [' MQTT 主题 MQTT 主题将标识 AWS IoT 消息。']
# embedding language: chinese
# append_num: 3
# text_append:  MQTT 主题 MQTT 主题将标识 AWS IoT 消息。,AWS IoT 客户端通过向消息提供主题名称来标识其发布的消息。,客户端 通过将主题筛选条件注册到 AWS IoT Core 来标识要订阅（接收）的消息。
# ind  1599 ,len: 32 text: ['AWS IoT 客户端通过向消息提供主题名称来标识其发布的消息。']
# embedding language: chinese
# append_num: 3
# text_append: AWS IoT 客户端通过向消息提供主题名称来标识其发布的消息。,客户端 通过将主题筛选条件注册到 AWS IoT Core 来标识要订阅（接收）的消息。,消息代理使用主题名称和主题筛 选条件将消息从发布客户端传输到订阅客户端。
# ind  1600 ,len: 44 text: ['客户端 通过将主题筛选条件注册到 AWS IoT Core 来标识要订阅（接收）的消息。']
# embedding language: chinese
# append_num: 3
# text_append: 客户端 通过将主题筛选条件注册到 AWS IoT Core 来标识要订阅（接收）的消息。,消息代理使用主题名称和主题筛 选条件将消息从发布客户端传输到订阅客户端。, 消息代理使用主题来识别使用 MQTT 发送的消息以及使用 HTTP 发送到 HTTPS 消息 URL  (p. 96) 的消 息。
# ind  1601 ,len: 36 text: ['消息代理使用主题名称和主题筛 选条件将消息从发布客户端传输到订阅客户端。']
# embedding language: chinese
# append_num: 3
# text_append: 消息代理使用主题名称和主题筛 选条件将消息从发布客户端传输到订阅客户端。, 消息代理使用主题来识别使用 MQTT 发送的消息以及使用 HTTP 发送到 HTTPS 消息 URL  (p. 96) 的消 息。, 虽然 AWS IoT 支持某些 保留的系统主题  (p. 101)，但大多数 MQTT 主题是由您（即系统设计人员）创建和 管理的。
# ind  1602 ,len: 66 text: [' 消息代理使用主题来识别使用 MQTT 发送的消息以及使用 HTTP 发送到 HTTPS 消息 URL  (p. 96) 的消 息。']
# embedding language: chinese
# append_num: 3
# text_append:  消息代理使用主题来识别使用 MQTT 发送的消息以及使用 HTTP 发送到 HTTPS 消息 URL  (p. 96) 的消 息。, 虽然 AWS IoT 支持某些 保留的系统主题  (p. 101)，但大多数 MQTT 主题是由您（即系统设计人员）创建和 管理的。,AWS IoT 使用主题识别从发布客户端接收的消息，并选择要发送到订阅客户端的消息，如以下各节 所述。
# ind  1603 ,len: 67 text: [' 虽然 AWS IoT 支持某些 保留的系统主题  (p. 101)，但大多数 MQTT 主题是由您（即系统设计人员）创建和 管理的。']
# embedding language: chinese
# append_num: 3
# text_append:  虽然 AWS IoT 支持某些 保留的系统主题  (p. 101)，但大多数 MQTT 主题是由您（即系统设计人员）创建和 管理的。,AWS IoT 使用主题识别从发布客户端接收的消息，并选择要发送到订阅客户端的消息，如以下各节 所述。,在为系统创建主题命名空间之前，请查看 MQTT 主题的特征，以创建最适合您的 IoT 系统的主题名称 层次结构。
# ind  1604 ,len: 51 text: ['AWS IoT 使用主题识别从发布客户端接收的消息，并选择要发送到订阅客户端的消息，如以下各节 所述。']
# embedding language: chinese
# append_num: 3
# text_append: AWS IoT 使用主题识别从发布客户端接收的消息，并选择要发送到订阅客户端的消息，如以下各节 所述。,在为系统创建主题命名空间之前，请查看 MQTT 主题的特征，以创建最适合您的 IoT 系统的主题名称 层次结构。, 主题名称 主题名称和主题筛选条件是 UTF-8 编码的字符串。
# ind  1605 ,len: 56 text: ['在为系统创建主题命名空间之前，请查看 MQTT 主题的特征，以创建最适合您的 IoT 系统的主题名称 层次结构。']
# embedding language: chinese
# append_num: 3
# text_append: 在为系统创建主题命名空间之前，请查看 MQTT 主题的特征，以创建最适合您的 IoT 系统的主题名称 层次结构。, 主题名称 主题名称和主题筛选条件是 UTF-8 编码的字符串。,它们可以使用正斜杠 (/) 字符分隔层次结构的级别来表示 信息的层次结构。
# ind  1606 ,len: 32 text: [' 主题名称 主题名称和主题筛选条件是 UTF-8 编码的字符串。']
# embedding language: chinese
# append_num: 3
# text_append:  主题名称 主题名称和主题筛选条件是 UTF-8 编码的字符串。,它们可以使用正斜杠 (/) 字符分隔层次结构的级别来表示 信息的层次结构。,例如，此主题名称可以引用房间 1 中的温度传感器： •sensor/temperature/room1 在此示例中，其他房间中可能还有其它类型的传感器，其主题名称如下： 99
# ind  1607 ,len: 37 text: ['它们可以使用正斜杠 (/) 字符分隔层次结构的级别来表示 信息的层次结构。']
# embedding language: chinese
# append_num: 3
# text_append: 它们可以使用正斜杠 (/) 字符分隔层次结构的级别来表示 信息的层次结构。,例如，此主题名称可以引用房间 1 中的温度传感器： •sensor/temperature/room1 在此示例中，其他房间中可能还有其它类型的传感器，其主题名称如下： 99,AWS IoT Core 开发人员指南 MQTT 主题 •sensor/temperature/room2 •sensor/humidity/room1 •sensor/humidity/room2 Note 在考虑系统中消息的主题名称时，请记住： •主题名称和主题筛选条件区分大小写。
# ind  1608 ,len: 87 text: ['例如，此主题名称可以引用房间 1 中的温度传感器： •sensor/temperature/room1 在此示例中，其他房间中可能还有其它类型的传感器，其主题名称如下： 99']
# embedding language: chinese
# append_num: 3
# text_append: 例如，此主题名称可以引用房间 1 中的温度传感器： •sensor/temperature/room1 在此示例中，其他房间中可能还有其它类型的传感器，其主题名称如下： 99,AWS IoT Core 开发人员指南 MQTT 主题 •sensor/temperature/room2 •sensor/humidity/room1 •sensor/humidity/room2 Note 在考虑系统中消息的主题名称时，请记住： •主题名称和主题筛选条件区分大小写。, •主题名称不得包含个人身份信息。
# ind  1609 ,len: 143 text: ['AWS IoT Core 开发人员指南 MQTT 主题 •sensor/temperature/room2 •sensor/humidity/room1 •sensor/humidity/room2 Note 在考虑系统中消息的主题名称时，请记住： •主题名称和主题筛选条件区分大小写。']
# embedding language: chinese
# append_num: 3
# text_append: AWS IoT Core 开发人员指南 MQTT 主题 •sensor/temperature/room2 •sensor/humidity/room1 •sensor/humidity/room2 Note 在考虑系统中消息的主题名称时，请记住： •主题名称和主题筛选条件区分大小写。, •主题名称不得包含个人身份信息。, •以 $ 开头的主题名称均为只能由 AWS IoT Core 使用的 预留主题  (p. 101)。
# ind  1610 ,len: 17 text: [' •主题名称不得包含个人身份信息。']
# embedding language: chinese
# append_num: 3
# text_append:  •主题名称不得包含个人身份信息。, •以 $ 开头的主题名称均为只能由 AWS IoT Core 使用的 预留主题  (p. 101)。, •AWS IoT Core 无法在AWS 账户或区域之间发送或接收消息。
# ind  1611 ,len: 51 text: [' •以 $ 开头的主题名称均为只能由 AWS IoT Core 使用的 预留主题  (p. 101)。']
# embedding language: chinese
# append_num: 3
# text_append:  •以 $ 开头的主题名称均为只能由 AWS IoT Core 使用的 预留主题  (p. 101)。, •AWS IoT Core 无法在AWS 账户或区域之间发送或接收消息。, 有关设计主题名称和命名空间的更多信息，请参阅我们的白皮书《 为 AWS IoT Core Core 设计 MQTT 主 题》。
# ind  1612 ,len: 37 text: [' •AWS IoT Core 无法在AWS 账户或区域之间发送或接收消息。']
# embedding language: chinese
# append_num: 3
# text_append:  •AWS IoT Core 无法在AWS 账户或区域之间发送或接收消息。, 有关设计主题名称和命名空间的更多信息，请参阅我们的白皮书《 为 AWS IoT Core Core 设计 MQTT 主 题》。, 有关应用程序如何发布和订阅消息的示例，请从 AWS IoT Core 入门  (p. 16) 和 AWS IoT Device  SDK、Mobile SDK 和 AWS IoT Device Client  (p. 1302 ) 开始查阅。
# ind  1613 ,len: 64 text: [' 有关设计主题名称和命名空间的更多信息，请参阅我们的白皮书《 为 AWS IoT Core Core 设计 MQTT 主 题》。']
# embedding language: chinese
# append_num: 3
# text_append:  有关设计主题名称和命名空间的更多信息，请参阅我们的白皮书《 为 AWS IoT Core Core 设计 MQTT 主 题》。, 有关应用程序如何发布和订阅消息的示例，请从 AWS IoT Core 入门  (p. 16) 和 AWS IoT Device  SDK、Mobile SDK 和 AWS IoT Device Client  (p. 1302 ) 开始查阅。, Important 主题命名空间仅限于AWS 账户和区域。
# ind  1614 ,len: 122 text: [' 有关应用程序如何发布和订阅消息的示例，请从 AWS IoT Core 入门  (p. 16) 和 AWS IoT Device  SDK、Mobile SDK 和 AWS IoT Device Client  (p. 1302 ) 开始查阅。']
# embedding language: chinese
# append_num: 3
# text_append:  有关应用程序如何发布和订阅消息的示例，请从 AWS IoT Core 入门  (p. 16) 和 AWS IoT Device  SDK、Mobile SDK 和 AWS IoT Device Client  (p. 1302 ) 开始查阅。, Important 主题命名空间仅限于AWS 账户和区域。,例如，一个区域中的某个AWS 账户使用的 sensor/temp/ room1  主题与另一个区域中的同一AWS账户或任何区域中的任何其它 AWS 账户 使用的 sensor/ temp/room1  主题不同。
# ind  1615 ,len: 30 text: [' Important 主题命名空间仅限于AWS 账户和区域。']
# embedding language: chinese
# append_num: 3
# text_append:  Important 主题命名空间仅限于AWS 账户和区域。,例如，一个区域中的某个AWS 账户使用的 sensor/temp/ room1  主题与另一个区域中的同一AWS账户或任何区域中的任何其它 AWS 账户 使用的 sensor/ temp/room1  主题不同。, 主题 ARN 所有主题 ARN (Amazon Resource Name) 都采用以下形式： arn:aws:iot: aws-region :AWS-account-ID :topic/Topic 例如，arn:aws:iot:us-west-2:123EXAMPLE456:topic/application/topic/device/sensor 是主题  application/topic/device/sensor  的 ARN。
# ind  1616 ,len: 106 text: ['例如，一个区域中的某个AWS 账户使用的 sensor/temp/ room1  主题与另一个区域中的同一AWS账户或任何区域中的任何其它 AWS 账户 使用的 sensor/ temp/room1  主题不同。']
# embedding language: chinese
# append_num: 3
# text_append: 例如，一个区域中的某个AWS 账户使用的 sensor/temp/ room1  主题与另一个区域中的同一AWS账户或任何区域中的任何其它 AWS 账户 使用的 sensor/ temp/room1  主题不同。, 主题 ARN 所有主题 ARN (Amazon Resource Name) 都采用以下形式： arn:aws:iot: aws-region :AWS-account-ID :topic/Topic 例如，arn:aws:iot:us-west-2:123EXAMPLE456:topic/application/topic/device/sensor 是主题  application/topic/device/sensor  的 ARN。, 主题筛选条件 订阅客户端会向消息代理注册主题筛选条件，以指定消息代理应将消息发送到的主题。
# ind  1617 ,len: 223 text: [' 主题 ARN 所有主题 ARN (Amazon Resource Name) 都采用以下形式： arn:aws:iot: aws-region :AWS-account-ID :topic/Topic 例如，arn:aws:iot:us-west-2:123EXAMPLE456:topic/application/topic/device/sensor 是主题  application/topic/device/sensor  的 ARN。']
# embedding language: chinese
# append_num: 3
# text_append:  主题 ARN 所有主题 ARN (Amazon Resource Name) 都采用以下形式： arn:aws:iot: aws-region :AWS-account-ID :topic/Topic 例如，arn:aws:iot:us-west-2:123EXAMPLE456:topic/application/topic/device/sensor 是主题  application/topic/device/sensor  的 ARN。, 主题筛选条件 订阅客户端会向消息代理注册主题筛选条件，以指定消息代理应将消息发送到的主题。,主题筛选条件可以是 用于订阅单个主题的单个主题名称，也可以包含通配符以同时订阅多个主题名称。
# ind  1618 ,len: 46 text: [' 主题筛选条件 订阅客户端会向消息代理注册主题筛选条件，以指定消息代理应将消息发送到的主题。']
# embedding language: chinese
# append_num: 3
# text_append:  主题筛选条件 订阅客户端会向消息代理注册主题筛选条件，以指定消息代理应将消息发送到的主题。,主题筛选条件可以是 用于订阅单个主题的单个主题名称，也可以包含通配符以同时订阅多个主题名称。, 发布客户端无法在其发布的主题名称中使用通配符。
# ind  1619 ,len: 46 text: ['主题筛选条件可以是 用于订阅单个主题的单个主题名称，也可以包含通配符以同时订阅多个主题名称。']
# embedding language: chinese
# append_num: 3
# text_append: 主题筛选条件可以是 用于订阅单个主题的单个主题名称，也可以包含通配符以同时订阅多个主题名称。, 发布客户端无法在其发布的主题名称中使用通配符。, 下表列出了可在主题筛选条件中使用的通配符。
# ind  1620 ,len: 24 text: [' 发布客户端无法在其发布的主题名称中使用通配符。']
# embedding language: chinese
# append_num: 3
# text_append:  发布客户端无法在其发布的主题名称中使用通配符。, 下表列出了可在主题筛选条件中使用的通配符。, 主题通配符 通配符 匹配项 注意 # 主题层次结构中位于其级别及其 以下的所有字符串。
# ind  1621 ,len: 22 text: [' 下表列出了可在主题筛选条件中使用的通配符。']
# embedding language: chinese
# append_num: 3
# text_append:  下表列出了可在主题筛选条件中使用的通配符。, 主题通配符 通配符 匹配项 注意 # 主题层次结构中位于其级别及其 以下的所有字符串。,必须是主题筛选条件中的最后一 个字符。
# ind  1622 ,len: 44 text: [' 主题通配符 通配符 匹配项 注意 # 主题层次结构中位于其级别及其 以下的所有字符串。']
# embedding language: chinese
# append_num: 3
# text_append:  主题通配符 通配符 匹配项 注意 # 主题层次结构中位于其级别及其 以下的所有字符串。,必须是主题筛选条件中的最后一 个字符。, 必须是其主题层次结构级别中的 唯一字符。
# ind  1623 ,len: 19 text: ['必须是主题筛选条件中的最后一 个字符。']
# embedding language: chinese
# append_num: 3
# text_append: 必须是主题筛选条件中的最后一 个字符。, 必须是其主题层次结构级别中的 唯一字符。, 可以在还包含 + 通配符的主题筛 选条件中使用。
# ind  1624 ,len: 21 text: [' 必须是其主题层次结构级别中的 唯一字符。']
# embedding language: chinese
# append_num: 3
# text_append:  必须是其主题层次结构级别中的 唯一字符。, 可以在还包含 + 通配符的主题筛 选条件中使用。, 100
# ind  1625 ,len: 25 text: [' 可以在还包含 + 通配符的主题筛 选条件中使用。']
# embedding language: chinese
# append_num: 3
# text_append:  可以在还包含 + 通配符的主题筛 选条件中使用。, 100,AWS IoT Core 开发人员指南 MQTT 主题 通配符 匹配项 注意 + 级别中包含字符的任何字符串。
# ind  1626 ,len: 4 text: [' 100']
# embedding language: chinese
# append_num: 3
# text_append:  100,AWS IoT Core 开发人员指南 MQTT 主题 通配符 匹配项 注意 + 级别中包含字符的任何字符串。, 必须是其主题层次结构级别中的 唯一字符。
# ind  1627 ,len: 55 text: ['AWS IoT Core 开发人员指南 MQTT 主题 通配符 匹配项 注意 + 级别中包含字符的任何字符串。']
# embedding language: chinese
# append_num: 3
# text_append: AWS IoT Core 开发人员指南 MQTT 主题 通配符 匹配项 注意 + 级别中包含字符的任何字符串。, 必须是其主题层次结构级别中的 唯一字符。, 可在主题筛选条件的多个级别中 使用。
# ind  1628 ,len: 21 text: [' 必须是其主题层次结构级别中的 唯一字符。']
# embedding language: chinese
# append_num: 3
# text_append:  必须是其主题层次结构级别中的 唯一字符。, 可在主题筛选条件的多个级别中 使用。, 将通配符用于之前的传感器主题名称示例： •sensor/#  订阅接收发布到 sensor/ 、sensor/temperature  和 sensor/temperature/room1  的消 息，但不会接收发布到 sensor  的消息。
# ind  1629 ,len: 19 text: [' 可在主题筛选条件的多个级别中 使用。']
# embedding language: chinese
# append_num: 3
# text_append:  可在主题筛选条件的多个级别中 使用。, 将通配符用于之前的传感器主题名称示例： •sensor/#  订阅接收发布到 sensor/ 、sensor/temperature  和 sensor/temperature/room1  的消 息，但不会接收发布到 sensor  的消息。, •sensor/+/room1  订阅接收发布到 sensor/temperature/room1  和 sensor/humidity/room1  的 消息，但不会接收发布到 sensor/temperature/room2  或 sensor/humidity/room2  的消息。
# ind  1630 ,len: 123 text: [' 将通配符用于之前的传感器主题名称示例： •sensor/#  订阅接收发布到 sensor/ 、sensor/temperature  和 sensor/temperature/room1  的消 息，但不会接收发布到 sensor  的消息。']
# embedding language: chinese
# append_num: 3
# text_append:  将通配符用于之前的传感器主题名称示例： •sensor/#  订阅接收发布到 sensor/ 、sensor/temperature  和 sensor/temperature/room1  的消 息，但不会接收发布到 sensor  的消息。, •sensor/+/room1  订阅接收发布到 sensor/temperature/room1  和 sensor/humidity/room1  的 消息，但不会接收发布到 sensor/temperature/room2  或 sensor/humidity/room2  的消息。, 主题筛选条件 ARN 所有主题筛选条件 ARN (Amazon Resource Name) 都采用以下形式： arn:aws:iot: aws-region :AWS-account-ID :topicfilter/ TopicFilter 例如，arn:aws:iot:us-west-2:123EXAMPLE456:topicfilter/application/topic/+/sensor 是主题筛选条件  application/topic/+/sensor  的 ARN。
# ind  1631 ,len: 146 text: [' •sensor/+/room1  订阅接收发布到 sensor/temperature/room1  和 sensor/humidity/room1  的 消息，但不会接收发布到 sensor/temperature/room2  或 sensor/humidity/room2  的消息。']
# embedding language: chinese
# append_num: 3
# text_append:  •sensor/+/room1  订阅接收发布到 sensor/temperature/room1  和 sensor/humidity/room1  的 消息，但不会接收发布到 sensor/temperature/room2  或 sensor/humidity/room2  的消息。, 主题筛选条件 ARN 所有主题筛选条件 ARN (Amazon Resource Name) 都采用以下形式： arn:aws:iot: aws-region :AWS-account-ID :topicfilter/ TopicFilter 例如，arn:aws:iot:us-west-2:123EXAMPLE456:topicfilter/application/topic/+/sensor 是主题筛选条件  application/topic/+/sensor  的 ARN。, MQTT 消息负载 您的 MQTT 消息中发送的消息有效负载并不由 AWS IoT 指定，除非是用于 the section called “保留的主 题” (p. 101) 中的一个。
# ind  1632 ,len: 244 text: [' 主题筛选条件 ARN 所有主题筛选条件 ARN (Amazon Resource Name) 都采用以下形式： arn:aws:iot: aws-region :AWS-account-ID :topicfilter/ TopicFilter 例如，arn:aws:iot:us-west-2:123EXAMPLE456:topicfilter/application/topic/+/sensor 是主题筛选条件  application/topic/+/sensor  的 ARN。']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_14324/1408929597.py in <cell line: 16>()
#      14
#      15 now1 = datetime.now()#begin time
# ---> 16 loaded_files = search_qa.init_knowledge_vector(local_file,bulk_size,language)
#      17 now2 = datetime.now()#endtime
#      18 print("File import takes time:",now2-now1)
#
# ~/SageMaker/isearchjupyter/data_load/smart_search.py in init_knowledge_vector(self, filepath, bulk_size, language)
#     200                 texts = [d.page_content for d in docs]
#     201                 metadatas = [d.metadata for d in docs]
# --> 202                 ids = self.vector_store.add_texts(texts, metadatas, bulk_size=bulk_size, language=language)
#     203                 return loaded_files
#     204             else:
#
# ~/SageMaker/isearchjupyter/data_load/langchain/vectorstores/opensearch_vector_search.py in add_texts(self, texts, metadatas, bulk_size, **kwargs)
#     331         """
#     332         language = _get_kwargs_value(kwargs, "language", "chinese")
# --> 333         embeddings,new_texts,new_metadatas = self.embedding_function.embed_documents(list(texts),list(metadatas),language=language)
#     334         print("finish embedding, text len:",len(new_texts),len(embeddings))
#     335
#
# ~/SageMaker/isearchjupyter/data_load/langchain/embeddings/sagemaker_endpoint.py in embed_documents(self, texts, metadatas, chunk_size, language)
#     196             try:
#     197                 print('ind ',i,',len:',len(texts[i: i+_chunk_size][0]),'text:',texts[i: i+_chunk_size])
# --> 198                 response = self._embedding_func(list(texts[i: i+_chunk_size]))
#     199                 results.append(response)
#     200
#
# ~/SageMaker/isearchjupyter/data_load/langchain/embeddings/sagemaker_endpoint.py in _embedding_func(self, texts)
#     163             raise ValueError(f"Error raised by inference endpoint: {e}")
#     164
# --> 165         return self.content_handler.transform_output(response["Body"])
#     166
#     167     def embed_documents(
#
# ~/SageMaker/isearchjupyter/data_load/smart_search.py in transform_output(self, output)
#      69
#      70         def transform_output(self, output: bytes) -> List[List[float]]:
# ---> 71             response_json = json.loads(output.read().decode("utf-8"))
#      72             if endpoint_name.find("text2vec-base-chinese") >= 0:
#      73                 return response_json[0][0][0]
#
# ~/anaconda3/envs/pytorch_p39/lib/python3.9/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     344             parse_int is None and parse_float is None and
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#     348         cls = JSONDecoder
#
# ~/anaconda3/envs/pytorch_p39/lib/python3.9/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~/anaconda3/envs/pytorch_p39/lib/python3.9/json/decoder.py in raw_decode(self, s, idx)
#     351         """
#     352         try:
# --> 353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
#     355             raise JSONDecodeError("Expecting value", s, err.value) from None
#
# KeyboardInterrupt:
